# %% [markdown]
# # TGFB1 Part 1 - Importing the data
#
# In this notebook, we take the data from the matrix, gene and cell files and create an AnnData matrix we can use for future analyses.

# %% [markdown]
# # Before this notebook was executed, we have aligned our data using these steps:
#
# https://docs.google.com/document/d/1HI_tOIbaw0x1jzzINAAwBlj__7eSiFfDaIO43Hux2D4/edit?usp=sharing

# %%
# !echo hi
# Out:
# hi

# %%
from collections import defaultdict

import numpy as np
import pandas
import scanpy
import scanpy as sc
import anndata
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/numba/errors.py:105: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# scanpy==1.4 anndata==0.6.19 numpy==1.16.3 scipy==1.2.1 pandas==0.24.2 scikit-learn==0.20.3 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# # Barcode filtering
#
# In order to filter the barcodes, we will open the barcodes done through Cell Ranger and return a set of the barcodes we want to filter the dropest matrix by. It is of the format:
#
#     AAACCTGAGACATAAC-1
#
# where ``AAACCTGAGACATAAC`` is a nucleotide barcode and ``1`` is the batch it corresponds to. We load this into a dictionary mapping barcodes to batches. We will not use the batches in the AnnData matrix, but it is still useful to cross-reference.

# %%
def get_barcode_set(path):
    barcodes = {}

    with open("barcodes.tsv", "r") as f:
        for line in f:
            barcode, batch = line.rstrip().split('-')
            batch = int(batch)
            
            barcodes[barcode] = batch
    
    return barcodes

# %% [markdown]
# Populate the dictionary from the Cell Ranger set.

# %%
pawel_barcodes = get_barcode_set("barcodes.tsv")
len(pawel_barcodes)
# Out:
# 12267

# %% [markdown]
# # Loading genes
#
# Create a function to load all the gene data from the dimension 1 CSV file, creating a list mapping gene IDs to genes.
#
# The gene file is of the format:
#
#     "1","TGFB1"
#
# where `1` is a strictly increasing gene ID as found in the count matrix and `TGFB1` is the name of the gene. Create a list whose `n`th index is the name of the corresponding gene ID.

# %%
def load_genes(batch, variant):
    genes_result = []
    genes_path = "source/{}_{}_dim1.csv".format(batch, variant)

    with open(genes_path, "r") as genes:
        line_no = 0

        for gene in genes:
            if not line_no:
                line_no += 1
                continue

            id, name = gene.rstrip().replace('"', '').split(",")
            id = int(id)
            
            # These should be strictly increasing.
            assert id == line_no

            genes_result.append(name)
            line_no += 1
    
    return genes_result

# %%
genes1 = set(load_genes("S1", "exon"))
genes1
# Out:
# {'AC096708.3',
#  'RPL7P35',
#  'ZNF609',
#  'FAM98B',
#  'AL049794.1',
#  'OSTN',
#  'AL031595.1',
#  'CACNA2D2',
#  'MFSD14A',
#  'CARD11',
#  'CHMP4A',
#  'SSBP3-AS1',
#  'NRIP3',
#  'AC004540.1',
#  'POLR3E',
#  'NPY1R',
#  'SULT1E1',
#  'ZNF630-AS1',
#  'CCNQ',
#  'IPO9',
#  'UPF2',
#  'P2RX6',
#  'IGLON5',
#  'DKC1',
#  'SYDE1',
#  'NUFIP2',
#  'RPL21P126',
#  'AC008592.5',
#  'AC012146.2',
#  'AL162584.1',
#  'REEP4',
#  'CIZ1',
#  'ZRANB3',
#  'NDUFS3',
#  'PPIEL',
#  'Z97985.1',
#  'ABLIM3',
#  'AC016027.2',
#  'RN7SL23P',
#  'IGF2BP2-AS1',
#  'CNFN',
#  'AP003717.3',
#  'AL138966.2',
#  'SLC9A8',
#  'PLXNA3',
#  'TBRG1',
#  'NOX4',
#  'LINC00167',
#  'ODCP',
#  'ZNF841',
#  'FER1L6-AS1',
#  'FLAD1',
#  'PYGO1',
#  'ZUP1',
#  'SMG8',
#  'CHCHD4',
#  'DCP1B',
#  'MIB2',
#  'AC121338.2',
#  'PIEZO2',
#  'ZHX2',
#  'RHOB',
#  'ZNF672',
#  'MAPRE2',
#  'LINC00543',
#  'SOCS5P2',
#  'AC136285.3',
#  'AL121894.2',
#  'AP001029.3',
#  'AC063944.3',
#  'BX539320.1',
#  'AC245100.8',
#  'AL158212.4',
#  'AC134775.1',
#  'CCNT2',
#  'ERH',
#  'AC078778.1',
#  'SMAD5',
#  'TMEM59L',
#  'AC011468.3',
#  'HIST1H2BO',
#  'DNAJB2',
#  'RPL17P43',
#  'MEGF6',
#  'RNU6-1005P',
#  'ACTN1',
#  'NAT16',
#  'STX8P1',
#  'LINC01801',
#  'RPL12P17',
#  'KMT2B',
#  'ZNF134',
#  'GALNT15',
#  'AL359918.1',
#  'REPIN1',
#  'P2RX1',
#  'MLLT1',
#  'AL627389.1',
#  'CATSPER1',
#  'AC103988.1',
#  'IRS2',
#  'AC112198.2',
#  'AC012486.1',
#  'NDUFA13',
#  'AC026979.3',
#  'PDSS1',
#  'AP000860.1',
#  'AC099548.2',
#  'UHRF2',
#  'AC004771.2',
#  'AQP5',
#  'AC090709.1',
#  'U73166.1',
#  'CORIN',
#  'CXXC1',
#  'AC016583.1',
#  'AL049840.5',
#  'ZNF765',
#  'AP1B1',
#  'EEF1A1P25',
#  'CR381670.1',
#  'RPSA',
#  'AC113139.1',
#  'AL121957.1',
#  'HNRNPMP1',
#  'PCDHGC5',
#  'AC007342.7',
#  'AL162254.1',
#  'FAM90A1',
#  'AL356481.1',
#  'MIR4435-2HG',
#  'CRHR2',
#  'IKZF2',
#  'MYH3',
#  'E2F4',
#  'IAH1',
#  'LINC00824',
#  'STBD1',
#  'SALL2',
#  'DCAF4L1',
#  'AP001269.1',
#  'LINC02356',
#  'AP002490.2',
#  'TCF20',
#  'ANKMY1',
#  'AC211486.1',
#  'AC008126.1',
#  'KRR1P1',
#  'WAS',
#  'TSPEAR-AS1',
#  'ZBTB37',
#  'SLC44A2',
#  'RHOU',
#  'ST20',
#  'AC104170.2',
#  'CDK14',
#  'ARPIN',
#  'HEPHL1',
#  'MTATP6P1',
#  'IMMP1L',
#  'PCMTD2',
#  'GNB4',
#  'TAS2R10',
#  'USP7',
#  'GPR155',
#  'ASF1B',
#  'ZNF197-AS1',
#  'AC104339.1',
#  'RRAS2',
#  'MRPS31',
#  'AC010894.2',
#  'RN7SL364P',
#  'ZNF485',
#  'SIPA1L1',
#  'PHB2',
#  'MIR31HG',
#  'EPOR',
#  'TRPM4',
#  'AC073911.3',
#  'S100A10',
#  'CELF1',
#  'AC027796.2',
#  'FRMD8',
#  'AC068587.4',
#  'AC111200.1',
#  'TGFBI',
#  'AL009174.1',
#  'PPP4C',
#  'PDE4B',
#  'OR2C3',
#  'RPS4Y1',
#  'AC026310.3',
#  'RN7SL113P',
#  'RF00409',
#  'ANKK1',
#  'PSMB3',
#  'EPHA10',
#  'AC109630.1',
#  'AC090186.1',
#  'EED',
#  'AL138960.1',
#  'RPSAP29',
#  'TMSB4Y',
#  'RPL23AP36',
#  'AC046185.2',
#  'GTF2IP20',
#  'DNAJB11',
#  'ZNF324B',
#  'ZNF185',
#  'PPIAP9',
#  'SNED1',
#  'AL136531.1',
#  'CASP8',
#  'RPS23P5',
#  'AL034546.1',
#  'S100A2',
#  'AL157935.1',
#  'TACR1',
#  'RPA4',
#  'GABARAP',
#  'CEP97',
#  'NDUFB4P12',
#  'PRPF38A',
#  'OR52B6',
#  'RNPS1P1',
#  'ERCC5',
#  'AL133370.1',
#  'CERCAM',
#  'IL10RB',
#  'LINC02268',
#  'PLET1',
#  'FAM214B',
#  'BX119927.1',
#  'AC130371.2',
#  'GAB2',
#  'SCN5A',
#  'AL627171.2',
#  'RPL12P41',
#  'ARID1A',
#  'ARMC5',
#  'SPATA20',
#  'NXT1',
#  'GNPAT',
#  'CTAGE16P',
#  'KLF3-AS1',
#  'RBM5-AS1',
#  'AL133241.1',
#  'RPL23AP32',
#  'OR9K1P',
#  'ZBTB2',
#  'ANG',
#  'AC010931.2',
#  'NCF1',
#  'PSKH1',
#  'TENT4A',
#  'ZNF696',
#  'WDR48',
#  'UTP23',
#  'BCL2L14',
#  'AL031729.1',
#  'GTF2E1',
#  'AP003393.1',
#  'TAS2R1',
#  'LINC01978',
#  'AC010976.2',
#  'NDUFB8',
#  'CSAD',
#  'CDK1',
#  'SPDYE5',
#  'AC007879.2',
#  'MRPS17',
#  'CARNMT1',
#  'TRADD',
#  'MBD6',
#  'ADSS',
#  'REEP6',
#  'RPL10P15',
#  'AKIP1',
#  'AC018628.1',
#  'ALOX12P2',
#  'AC007224.2',
#  'RIC1',
#  'AC007610.4',
#  'GAPDHP32',
#  'AC018638.5',
#  'CUX1',
#  'AC015983.1',
#  'LINC01128',
#  'AC138207.6',
#  'PEAR1',
#  'ATP1A1-AS1',
#  'RPL23AP47',
#  'STC1',
#  'Z82217.1',
#  'AL136382.1',
#  'PER2',
#  'LINC00605',
#  'BOLA2-SMG1P6',
#  'UBE2I',
#  'AC015961.1',
#  'RPL30P7',
#  'MORN2',
#  'CALU',
#  'CRYL1',
#  'AL603750.1',
#  'F2RL3',
#  'DDX1',
#  'ZNF746',
#  'THUMPD3P1',
#  'INTS12',
#  'HLA-C',
#  'AC073052.1',
#  'UPK1A',
#  'STAG3L1',
#  'NPM1P18',
#  'TMEM130',
#  'AL691432.1',
#  'UBE2CP1',
#  'RBFOX2',
#  'AL365217.1',
#  'PLS1',
#  'PITX3',
#  'HIRA',
#  'HAS2',
#  'AC066616.1',
#  'MTIF2',
#  'SMG5',
#  'AC073082.1',
#  'BUD31',
#  'THBS4',
#  'RNF149',
#  'HDAC1',
#  'RPL13P6',
#  'KTI12',
#  'RBPJP2',
#  'AL136454.1',
#  'COX5B',
#  'MYO3B',
#  'OSBPL11',
#  'AL138955.1',
#  'SMURF2P1',
#  'AL356417.2',
#  'AC078785.1',
#  'SFT2D2',
#  'FGD5',
#  'RF00003',
#  'LTBP2',
#  'AC009264.1',
#  'SYTL3',
#  'AC008537.3',
#  'LRRC58',
#  'PLCXD3',
#  'RNU6-1301P',
#  'EHF',
#  'ATP13A1',
#  'TMTC4',
#  'FRAT1',
#  'KLHL2',
#  'KAT6B',
#  'TROVE2',
#  'AL020996.1',
#  'JPH1',
#  'ARID3A',
#  'ZCWPW1',
#  'RN7SL801P',
#  'GFRA1',
#  'KLF15',
#  'RPL35P9',
#  'AC025588.1',
#  'MARVELD1',
#  'TMED11P',
#  'GNB3',
#  'AL499616.1',
#  'DHDDS',
#  'ANXA2P1',
#  'AL118505.1',
#  'POLE',
#  'ART1',
#  'DLST',
#  'AP004609.3',
#  'GAB1',
#  'AL603832.1',
#  'FAM129A',
#  'ZNF133',
#  'AC009148.1',
#  'ABRAXAS1',
#  'BZW1P1',
#  'AC104653.1',
#  'AC027281.2',
#  'ELF1',
#  'LINC01560',
#  'UXT-AS1',
#  'RPL6P25',
#  'TRPV4',
#  'CSNK2B',
#  'KCTD18',
#  'TLE4',
#  'CTRB2',
#  'DEF8',
#  'FRMD4B',
#  'CAP2',
#  'SSBP3',
#  'RN7SL459P',
#  'AC007834.2',
#  'POLR3DP1',
#  'BTBD10',
#  'SLC1A5',
#  'SLCO2A1',
#  'CASC2',
#  'SNAPC1',
#  'KMT2C',
#  'ZNF788P',
#  'LINC00240',
#  'TMEM255A',
#  'BCKDHA',
#  'WHAMM',
#  'AL358075.3',
#  'AC021148.1',
#  'AP005432.1',
#  'ACKR1',
#  'AC073517.1',
#  'RBFOX1',
#  'BMS1P22',
#  'ASB16',
#  'AL139246.3',
#  'NDUFAF8',
#  'PRUNE1',
#  'RGN',
#  'AC112229.1',
#  'CBX1',
#  'ZRSR2',
#  'LNCOC1',
#  'PON2',
#  'LINC02094',
#  'HSFX3',
#  'AL034349.1',
#  'ACSF2',
#  'SYN1',
#  'AC073648.4',
#  'AC114763.1',
#  'AC015813.1',
#  'DGKQ',
#  'AL627308.1',
#  'RPS26P47',
#  'PDGFD',
#  'ACOXL',
#  'SMIM15-AS1',
#  'CCDC146',
#  'AL021407.1',
#  'IQGAP2',
#  'RPL36P16',
#  'OSBPL5',
#  'SEC31B',
#  'XPO6',
#  'AC007529.1',
#  'ERICH5',
#  'TMEM200C',
#  'SSR3',
#  'METTL8',
#  'AC093323.1',
#  'LRFN3',
#  'AC006213.6',
#  'AP000866.4',
#  'SMARCD3',
#  'KDELR2',
#  'AC004846.2',
#  'SNHG3',
#  'RBL2',
#  'AC104986.2',
#  'AL049776.1',
#  'GNB5',
#  'RNU4-1',
#  'AC104066.1',
#  'AC093214.1',
#  'AC011444.3',
#  'TRIM17',
#  'AL079342.2',
#  'ULK3',
#  'SPEF1',
#  'FAM171A2',
#  'SMARCD2',
#  'ZNF84',
#  'AL513534.1',
#  'AC013476.2',
#  'RPL9P9',
#  'OR10G3',
#  'USP8',
#  'RWDD4',
#  'KLF17',
#  'TRIM53BP',
#  'AC138932.5',
#  'RNU6-807P',
#  'MAGEA3',
#  'THUMPD2',
#  'SRY',
#  'AC106782.5',
#  'AC134349.2',
#  'GAPDHP68',
#  'CEP55',
#  'UQCRFS1P1',
#  'PGM5P4-AS1',
#  'ERICH4',
#  'ATP5PF',
#  'IFNG-AS1',
#  'RNF216',
#  'AL136320.1',
#  'DDRGK1',
#  'AC127455.1',
#  'SNORA53',
#  'EIF3LP3',
#  'GLTPD2',
#  'KCNIP3',
#  'VWCE',
#  'CDC42BPB',
#  'ACTN3',
#  'RPL29P12',
#  'AC026410.2',
#  'FIZ1',
#  'PPIAP34',
#  'AC138123.1',
#  'TFPI',
#  'CTD-2201I18.1',
#  'DERL1',
#  'EFCAB10',
#  'SLC35B3',
#  'NDUFB7',
#  'TRPC4',
#  'EIF3J',
#  'DUSP5',
#  'MKS1',
#  'LINC01048',
#  'HACD1',
#  'TRAK2',
#  'GNAL',
#  'PCAT6',
#  'XRCC4',
#  'RTEL1',
#  'ATP5PDP1',
#  'MED26',
#  'AL137026.1',
#  'LINC01844',
#  'CCL1',
#  'LINC02544',
#  'AC023509.6',
#  'RNY1P16',
#  'CCDC179',
#  'GMPR2',
#  'AL513320.1',
#  'YBX1P10',
#  'AC124319.2',
#  'CCT4P2',
#  'ENPEP',
#  'ZNF277',
#  'AC004893.1',
#  'C18orf21',
#  'YES1',
#  'KCNC1',
#  'ABCC10',
#  'AL138889.1',
#  'RNF19A',
#  'AC091492.1',
#  'AC131391.1',
#  'SOX9',
#  'SHANK2',
#  'ARIH2OS',
#  'LINC01356',
#  'B4GALNT1',
#  'AC010680.5',
#  'AC005865.1',
#  'PSME2P2',
#  'AC068733.2',
#  'LINC01338',
#  'NSD1',
#  'PKIB',
#  'ZNF602P',
#  'RASSF2',
#  'AL157832.3',
#  'CD163L1',
#  'AC005498.1',
#  'CACNG8',
#  'AL158823.1',
#  'ABHD18',
#  'ZNF584',
#  'AC245100.2',
#  'BATF',
#  'HNRNPF',
#  'BBS7',
#  'AC027279.4',
#  'CES1P1',
#  'VDAC1P3',
#  'NEDD4',
#  'AL109628.2',
#  'PHF10',
#  'KIZ',
#  'RPL23AP17',
#  'AC127164.1',
#  'CGREF1',
#  'TSTD3',
#  'CFAP157',
#  'MTCO2P12',
#  'AP002847.1',
#  'ADGRE1',
#  'ENGASE',
#  'C3orf70',
#  'AC141586.5',
#  'AC009948.3',
#  'OGFRP1',
#  'GALR3',
#  'NACC1',
#  'CIAO2B',
#  'SLC20A2',
#  'AC092296.2',
#  'AC004112.1',
#  'AC090204.1',
#  'TMEM140',
#  'AL031710.2',
#  'BX322639.1',
#  'AC018754.1',
#  'AC132192.2',
#  'TBCD',
#  'RN7SL331P',
#  'AP001024.1',
#  'PRAMEF12',
#  'ING4',
#  'RSU1',
#  'ZNF529',
#  'FAM229A',
#  'AL606495.1',
#  'LUZP2',
#  'AC022364.1',
#  'AL360175.1',
#  'TDRP',
#  'AC015802.5',
#  'ZNF783',
#  'FNDC7',
#  'AXDND1',
#  'PFN2',
#  'ZNF839P1',
#  'RPS3AP38',
#  'AC092794.2',
#  'AL365181.1',
#  'AC091614.1',
#  'AC016772.1',
#  'AC013267.1',
#  'OR5BJ1P',
#  'TIGIT',
#  'RPS5P3',
#  'FGGY',
#  'MYO15A',
#  'AC093249.4',
#  'AC020978.7',
#  'AC009237.3',
#  'UPK3B',
#  'LRRC8C',
#  'SPDYE2',
#  'SAC3D1',
#  'ARAP2',
#  'OGFOD1P1',
#  'GPRC5A',
#  'AC090114.3',
#  'ZNF33B',
#  'AC104634.1',
#  'AC099670.3',
#  'HHLA3',
#  'FIGN',
#  'CTU1',
#  'Z97055.1',
#  'BUB3',
#  'C21orf58',
#  'CCDC78',
#  'THSD1',
#  'SPTBN1',
#  'VNN1',
#  'AL354949.1',
#  'CHID1',
#  'SDHD',
#  'ETV2',
#  'RAMP2-AS1',
#  'AC115223.1',
#  'AC004801.1',
#  'AC023813.3',
#  'AC019186.1',
#  'AL606534.2',
#  'EEF1GP4',
#  'PPIAP30',
#  'AC107302.1',
#  'AC106900.1',
#  'FAM86KP',
#  'BRD7P4',
#  'RN7SL220P',
#  'KLF16',
#  'ATP6V0E2-AS1',
#  'CPAMD8',
#  'NPTXR',
#  'AC093151.3',
#  'ARHGEF33',
#  'IRAIN',
#  'AC025171.5',
#  'AP001330.5',
#  'MRPL3P1',
#  'OR2D3',
#  'VPS13A',
#  'MTND2P28',
#  'ELL2P1',
#  'CKS1BP2',
#  'NBDY',
#  'SMAD1',
#  'FBXO25',
#  'MIR218-1',
#  'AC104836.1',
#  'SIL1',
#  'POLA2',
#  'CYP2A6',
#  'CDC37P2',
#  'AC073111.5',
#  'LINC02598',
#  'CCDC71L',
#  'DOCK10',
#  'AC025062.1',
#  'CHRFAM7A',
#  'PTPRN2',
#  'TEX29',
#  'ZNF433-AS1',
#  'GPM6B',
#  'AL589935.1',
#  'OR7E2P',
#  'AC016949.1',
#  'UNC5B-AS1',
#  'AC122713.1',
#  'AC093635.1',
#  'HMGB1P27',
#  'DEFB109F',
#  'AL157384.1',
#  'PRRT3-AS1',
#  'SLC25A32',
#  'AL356234.1',
#  'IL34',
#  'AC145676.1',
#  'MSTN',
#  'TMEM202-AS1',
#  'PES1',
#  'ANO10',
#  'PA2G4',
#  'AC034207.1',
#  'ANKRD61',
#  'TRABD',
#  'RPS4XP8',
#  'SNRPCP10',
#  'AC116049.1',
#  'DCAF16',
#  'THOC3',
#  'PAQR6',
#  'KLHL42',
#  'AC105114.2',
#  'ZNF681',
#  'HCFC1R1',
#  'LANCL1-AS1',
#  'MMP1',
#  'DBP',
#  'AC124283.4',
#  'MT1X',
#  'OR10AH1P',
#  'KMT2E-AS1',
#  'AC006160.1',
#  'AC104532.2',
#  'CCDC85B',
#  'KY',
#  'SLC35G6',
#  'NHLRC1',
#  'LINC02130',
#  'SOD2',
#  'BCL7A',
#  'STK32B',
#  'SMC3',
#  'MON1B',
#  'CALCB',
#  'VAMP1',
#  'HAGHL',
#  'FBXO34',
#  'MXD3',
#  'AC004951.4',
#  'AC005220.1',
#  'RF02271',
#  'PAXX',
#  'MIP',
#  'MRPL40P1',
#  'SETP2',
#  'AC090877.1',
#  'MTND1P23',
#  'NUP210L',
#  'ATP6AP2',
#  'CNN1',
#  'GREM2',
#  'PLCD4',
#  'PPIAL4D',
#  'YWHAEP5',
#  'AC063950.1',
#  'SLC9A4',
#  'UFC1',
#  'AC026904.3',
#  'HSD17B13',
#  'ASPHD2',
#  'RN7SL748P',
#  'SMARCC1',
#  'SLC35C1',
#  'FBXO2',
#  'SH3BGRL2',
#  'AC013549.1',
#  'NALCN',
#  'AC241584.1',
#  'FAR1-IT1',
#  'INAFM1',
#  'BEND6',
#  'LETM1',
#  'AC090287.1',
#  'HNRNPA1P40',
#  'IQSEC3',
#  'TMED8',
#  'NDUFA3',
#  'DCAF6',
#  'SLAIN2',
#  'COQ4',
#  'INPP5E',
#  'AP000695.1',
#  'TNRC6A',
#  'DCAKD',
#  'AC126696.3',
#  'MBD3L2B',
#  'AC010531.6',
#  'LPAR1',
#  'ABHD12',
#  'SPRED3',
#  'AFF1',
#  'AC093227.1',
#  'ISL2',
#  'TEX46',
#  'TUBA1B',
#  'SALL4',
#  'CYP26B1',
#  'AC090543.1',
#  'AC025750.2',
#  'DALRD3',
#  'LINC01277',
#  'Z84484.1',
#  'PCF11',
#  'AC009053.1',
#  'HPGDS',
#  'POU4F3',
#  'MT1DP',
#  'MT2A',
#  'TRPS1',
#  'TUBBP5',
#  'LMAN1',
#  'AC021205.3',
#  'ATG4A',
#  'HNRNPA3P2',
#  'MCTP1',
#  'ZDHHC7',
#  'NBPF1',
#  'FKBPL',
#  'AC073896.5',
#  'BRIX1',
#  'MTFP1',
#  'C1QL4',
#  'AC005730.2',
#  'AC090453.1',
#  'FCRLA',
#  'EEF1A1',
#  'ZNF213-AS1',
#  'AC007842.1',
#  'MT1F',
#  'AC010680.2',
#  'AC011195.2',
#  'AC008543.3',
#  'LEXM',
#  'AL132996.1',
#  'FES',
#  'A4GNT',
#  'PLPP5',
#  'GYG2P1',
#  'AC093270.1',
#  'PCDHGB6',
#  'EDEM2',
#  'SDHA',
#  'MAP3K15',
#  'CDH23',
#  'ADH5P3',
#  'DDX19A',
#  'SLC4A7',
#  'PSMD9',
#  'RPL9P30',
#  'RPS15AP28',
#  'RPS19',
#  'ANKRD9',
#  'GCKR',
#  'AC103769.1',
#  'AC087072.2',
#  'TRPM3',
#  'DOCK9-DT',
#  'HS3ST2',
#  'DIMT1',
#  'UBE2D1',
#  'AC018755.4',
#  'ZNF311',
#  'APOA1-AS',
#  'PRDM11',
#  'C9orf153',
#  'RPS11P7',
#  'GID8',
#  'HS1BP3-IT1',
#  'AC004771.1',
#  'BRMS1',
#  'ATP5IF1',
#  'BCLAF3',
#  'PTGES',
#  'AC035140.1',
#  'FBXW4',
#  'VPS39',
#  'RCHY1',
#  'AC133555.3',
#  'AC007907.1',
#  'TBC1D8B',
#  'LTO1',
#  'PCOLCE',
#  'AP000753.2',
#  'AC023983.2',
#  'ZNF410',
#  'SLC39A3',
#  'AP003071.4',
#  'PFN4',
#  'RPS4XP18',
#  'NDUFAF4',
#  'MOCS1',
#  'MYO1G',
#  'AL138689.1',
#  'AC020661.4',
#  'AC012313.5',
#  'RN7SL846P',
#  'GOLGA8G',
#  'FAM114A1',
#  'CNTN1',
#  'SHLD2',
#  'AC099804.1',
#  'AC013549.2',
#  'TSSK6',
#  'ZC3HAV1',
#  'FLJ46284',
#  'AC083805.1',
#  'TIGD3',
#  'DCUN1D5',
#  'LINC01894',
#  'EXT2',
#  'JHY',
#  'AP002381.1',
#  'PYM1',
#  'KLHL20',
#  'PROB1',
#  'IFI44',
#  'AL022393.1',
#  'HMG20B',
#  'RORA',
#  'RPL12P33',
#  'C7orf25',
#  'HNRNPC',
#  'APH1B',
#  'ERN1',
#  'ACCS',
#  'NDUFAF6',
#  'SPIN4',
#  'EIPR1',
#  'INSL3',
#  'MRPL1',
#  'IL33',
#  'SLC12A6',
#  'AIFM2',
#  'FKBP11',
#  'AC008667.3',
#  'RASSF8-AS1',
#  'ARHGAP42',
#  'AP001442.1',
#  'ANKRD55',
#  'PGAP2',
#  'AL078612.2',
#  'AL133517.1',
#  'AC241377.2',
#  'VEZT',
#  'RPS3AP40',
#  'SV2A',
#  'RPL18P10',
#  'AL512791.2',
#  'RN7SL672P',
#  'ZSCAN18',
#  'AL389885.1',
#  'PMS2P7',
#  'AC079906.1',
#  'SVIL-AS1',
#  'DNAH7',
#  'AL451044.1',
#  'EXOSC7',
#  'AL136982.1',
#  ...}

# %%
genes2 = set(load_genes("S2", "exon"))
genes2
# Out:
# {'RPL7P35',
#  'ZNF609',
#  'FAM98B',
#  'AC005021.1',
#  'AL049794.1',
#  'OSTN',
#  'AC067852.2',
#  'CACNA2D2',
#  'MFSD14A',
#  'CHMP4A',
#  'SSBP3-AS1',
#  'NRIP3',
#  'POLR3E',
#  'SULT1E1',
#  'NPY1R',
#  'ZNF630-AS1',
#  'AL365203.1',
#  'CCNQ',
#  'IPO9',
#  'UPF2',
#  'P2RX6',
#  'DKC1',
#  'SYDE1',
#  'NUFIP2',
#  'RPL21P126',
#  'SERPINA1',
#  'AL162584.1',
#  'ACSBG2',
#  'REEP4',
#  'CIZ1',
#  'ZRANB3',
#  'AC117503.3',
#  'NDUFS3',
#  'PPIEL',
#  'ABLIM3',
#  'AC016027.2',
#  'RN7SL23P',
#  'IGF2BP2-AS1',
#  'CNFN',
#  'AC087879.1',
#  'AL138966.2',
#  'SLC9A8',
#  'PLXNA3',
#  'TBRG1',
#  'NOX4',
#  'LINC00167',
#  'ODCP',
#  'ZNF841',
#  'SEC14L4',
#  'FLAD1',
#  'PYGO1',
#  'ZUP1',
#  'LINC01102',
#  'SMG8',
#  'CHCHD4',
#  'MIB2',
#  'DCP1B',
#  'AC121338.2',
#  'PIEZO2',
#  'ZHX2',
#  'RHOB',
#  'ZNF672',
#  'LYPLA1P3',
#  'RNA5SP193',
#  'MAPRE2',
#  'LINC00543',
#  'AC136285.3',
#  'AL121894.2',
#  'AC133961.1',
#  'AP001029.3',
#  'AC063944.3',
#  'AC245100.8',
#  'AC010478.1',
#  'AC134775.1',
#  'CCNT2',
#  'ERH',
#  'AC078778.1',
#  'TMEM59L',
#  'SMAD5',
#  'AC011468.3',
#  'HIST1H2BO',
#  'DNAJB2',
#  'RPL17P43',
#  'MLLT10P1',
#  'MEGF6',
#  'AC011442.1',
#  'TAS2R6P',
#  'RNU6-1005P',
#  'ACTN1',
#  'STX8P1',
#  'LINC01801',
#  'RPL12P17',
#  'KMT2B',
#  'ZNF134',
#  'GALNT15',
#  'AL359918.1',
#  'REPIN1',
#  'P2RX1',
#  'AC139491.5',
#  'MLLT1',
#  'AL627389.1',
#  'CATSPER1',
#  'AC103988.1',
#  'IRS2',
#  'AC112198.2',
#  'NDUFA13',
#  'AC026979.3',
#  'PDSS1',
#  'AP000860.1',
#  'AC099548.2',
#  'UHRF2',
#  'AQP5',
#  'U73166.1',
#  'CORIN',
#  'CXXC1',
#  'AL049840.5',
#  'ZNF765',
#  'SPECC1L-ADORA2A',
#  'AP1B1',
#  'EEF1A1P25',
#  'CR381670.1',
#  'RPSA',
#  'KRT8P8',
#  'AC113139.1',
#  'AL121957.1',
#  'HNRNPMP1',
#  'RPL17P2',
#  'AC240565.2',
#  'RN7SL629P',
#  'AC007342.7',
#  'AL162254.1',
#  'FAM90A1',
#  'AL356481.1',
#  'MIR4435-2HG',
#  'LDLRAD4-AS1',
#  'CRHR2',
#  'MYH3',
#  'IKZF2',
#  'E2F4',
#  'IAH1',
#  'LINC00824',
#  'STBD1',
#  'SALL2',
#  'DCAF4L1',
#  'AP001269.1',
#  'LINC02356',
#  'AP002490.2',
#  'TCF20',
#  'ANKMY1',
#  'AL137002.2',
#  'AC211486.1',
#  'AC008126.1',
#  'KRR1P1',
#  'WAS',
#  'LINC02284',
#  'TSPEAR-AS1',
#  'ZBTB37',
#  'SLC44A2',
#  'RHOU',
#  'ST20',
#  'AC104170.2',
#  'CDK14',
#  'ARPIN',
#  'HEPHL1',
#  'MTATP6P1',
#  'IMMP1L',
#  'PCMTD2',
#  'GNB4',
#  'TAS2R10',
#  'USP7',
#  'GPR155',
#  'ASF1B',
#  'ZNF197-AS1',
#  'AC104339.1',
#  'RRAS2',
#  'MRPS31',
#  'AC010894.2',
#  'RN7SL364P',
#  'ZNF485',
#  'SIPA1L1',
#  'PHB2',
#  'MIR31HG',
#  'EPOR',
#  'TRPM4',
#  'AC091544.4',
#  'AC073911.3',
#  'S100A10',
#  'CELF1',
#  'EFL1P1',
#  'AC027796.2',
#  'FRMD8',
#  'AC068587.4',
#  'TGFBI',
#  'AL009174.1',
#  'PPP4C',
#  'PDE4B',
#  'OR2C3',
#  'AP003086.2',
#  'RPS4Y1',
#  'AC026310.3',
#  'RN7SL113P',
#  'RF00409',
#  'ANKK1',
#  'PSMB3',
#  'EPHA10',
#  'AC090186.1',
#  'EED',
#  'AL138960.1',
#  'RPSAP29',
#  'TMSB4Y',
#  'AC129510.1',
#  'LINC02060',
#  'RPL23AP36',
#  'AC046185.2',
#  'GTF2IP20',
#  'DNAJB11',
#  'ZNF324B',
#  'ZNF185',
#  'PPIAP9',
#  'SNED1',
#  'AL136531.1',
#  'CASP8',
#  'AL034546.1',
#  'RPS23P5',
#  'S100A2',
#  'AL157935.1',
#  'TACR1',
#  'RPA4',
#  'GABARAP',
#  'CEP97',
#  'NDUFB4P12',
#  'PRPF38A',
#  'RNPS1P1',
#  'ERCC5',
#  'AL133370.1',
#  'ITGAD',
#  'TUBB8P7',
#  'CERCAM',
#  'IL10RB',
#  'LINC02268',
#  'PLET1',
#  'FAM214B',
#  'BX119927.1',
#  'AC130371.2',
#  'GAB2',
#  'RPL12P41',
#  'AL627171.2',
#  'ARID1A',
#  'ARMC5',
#  'SPATA20',
#  'NXT1',
#  'GNPAT',
#  'KLF3-AS1',
#  'RBM5-AS1',
#  'RPL23AP32',
#  'ZBTB2',
#  'ANG',
#  'AC010931.2',
#  'NCF1',
#  'PSKH1',
#  'TENT4A',
#  'ZNF696',
#  'WDR48',
#  'UTP23',
#  'BCL2L14',
#  'AL031729.1',
#  'GTF2E1',
#  'AP003393.1',
#  'AC010976.2',
#  'LINC01978',
#  'NDUFB8',
#  'CSAD',
#  'CDK1',
#  'SPDYE5',
#  'AC007879.2',
#  'MRPS17',
#  'CARNMT1',
#  'TRADD',
#  'MBD6',
#  'ADSS',
#  'RPL10P15',
#  'AC018628.1',
#  'AKIP1',
#  'REEP6',
#  'ALOX12P2',
#  'HAO1',
#  'AJ003147.1',
#  'FAM84A',
#  'AC007224.2',
#  'RIC1',
#  'RN7SL89P',
#  'LINC01262',
#  'AC007610.4',
#  'GAPDHP32',
#  'AC018638.5',
#  'CUX1',
#  'AC015983.1',
#  'LINC01128',
#  'AC138207.6',
#  'PEAR1',
#  'ATP1A1-AS1',
#  'RPL23AP47',
#  'STC1',
#  'Z82217.1',
#  'AL136382.1',
#  'PER2',
#  'LINC00605',
#  'UBE2I',
#  'AC015961.1',
#  'RPL30P7',
#  'MORN2',
#  'CALU',
#  'CRYL1',
#  'AL603750.1',
#  'F2RL3',
#  'DDX1',
#  'ZNF746',
#  'THUMPD3P1',
#  'INTS12',
#  'HLA-C',
#  'AC073052.1',
#  'UPK1A',
#  'STAG3L1',
#  'NPM1P18',
#  'TMEM130',
#  'AL691432.1',
#  'RBFOX2',
#  'AC145423.2',
#  'AL365217.1',
#  'PLS1',
#  'PITX3',
#  'HIRA',
#  'HAS2',
#  'AC066616.1',
#  'MTIF2',
#  'SMG5',
#  'BUD31',
#  'THBS4',
#  'HDAC1',
#  'RNF149',
#  'RPL13P6',
#  'KTI12',
#  'RBPJP2',
#  'AL136454.1',
#  'COX5B',
#  'MYO3B',
#  'OSBPL11',
#  'AC104623.2',
#  'AL138955.1',
#  'AL356417.2',
#  'AC078785.1',
#  'SFT2D2',
#  'FGD5',
#  'RF00003',
#  'LTBP2',
#  'AC008537.3',
#  'SYTL3',
#  'LRRC58',
#  'EHF',
#  'ATP13A1',
#  'TMTC4',
#  'FRAT1',
#  'KLHL2',
#  'KAT6B',
#  'TROVE2',
#  'AL020996.1',
#  'ARID3A',
#  'ZCWPW1',
#  'GFRA1',
#  'KLF15',
#  'RPL35P9',
#  'AC025588.1',
#  'MARVELD1',
#  'TMED11P',
#  'GNB3',
#  'DHDDS',
#  'ANXA2P1',
#  'POLE',
#  'ART1',
#  'DLST',
#  'AP004609.3',
#  'GAB1',
#  'LINC02530',
#  'AL603832.1',
#  'FAM129A',
#  'ZNF133',
#  'AC009148.1',
#  'ABRAXAS1',
#  'AC104653.1',
#  'AC027281.2',
#  'ELF1',
#  'LINC01560',
#  'UXT-AS1',
#  'RPL6P25',
#  'TRPV4',
#  'CSNK2B',
#  'KCTD18',
#  'PRICKLE2-AS1',
#  'TLE4',
#  'DEF8',
#  'FRMD4B',
#  'CAP2',
#  'SSBP3',
#  'AC007834.2',
#  'POLR3DP1',
#  'BTBD10',
#  'SLC1A5',
#  'SLCO2A1',
#  'CASC2',
#  'SNAPC1',
#  'KMT2C',
#  'ZNF788P',
#  'LINC00240',
#  'BCKDHA',
#  'TMEM255A',
#  'WHAMM',
#  'AL358075.3',
#  'AC021148.1',
#  'AP005432.1',
#  'ACKR1',
#  'AC073517.1',
#  'RBFOX1',
#  'BMS1P22',
#  'ASB16',
#  'AL139246.3',
#  'NDUFAF8',
#  'PRUNE1',
#  'RGN',
#  'AC112229.1',
#  'AL121809.2',
#  'CBX1',
#  'ZRSR2',
#  'PON2',
#  'LINC02094',
#  'ACSF2',
#  'SYN1',
#  'AC073648.4',
#  'AC114763.1',
#  'AC015813.1',
#  'DGKQ',
#  'AL627308.1',
#  'RPS26P47',
#  'PDGFD',
#  'ACOXL',
#  'RPL17P3',
#  'CCDC146',
#  'AL021407.1',
#  'IQGAP2',
#  'RPL36P16',
#  'OSBPL5',
#  'SEC31B',
#  'XPO6',
#  'AC007529.1',
#  'ERICH5',
#  'TMEM200C',
#  'SSR3',
#  'METTL8',
#  'AC093323.1',
#  'AC016868.1',
#  'ONECUT3',
#  'LRFN3',
#  'AC006213.6',
#  'AP000866.4',
#  'SMARCD3',
#  'AC009054.1',
#  'KDELR2',
#  'AC004846.2',
#  'SNHG3',
#  'RBL2',
#  'AC104986.2',
#  'AL049776.1',
#  'AC087163.1',
#  'GNB5',
#  'AC104066.1',
#  'NPFFR2',
#  'ULK3',
#  'SPEF1',
#  'FAM171A2',
#  'SMARCD2',
#  'ZNF84',
#  'AL513534.1',
#  'AC013476.2',
#  'RPL9P9',
#  'RWDD4',
#  'USP8',
#  'KLF17',
#  'AC138932.5',
#  'RNU6-807P',
#  'SRY',
#  'THUMPD2',
#  'MAGEA3',
#  'AC106782.5',
#  'AC134349.2',
#  'GAPDHP68',
#  'CEP55',
#  'UQCRFS1P1',
#  'PGM5P4-AS1',
#  'ERICH4',
#  'ATP5PF',
#  'RNF216',
#  'AL136320.1',
#  'DDRGK1',
#  'COLCA2',
#  'SNORA53',
#  'EIF3LP3',
#  'GLTPD2',
#  'VWCE',
#  'KCNIP3',
#  'CDC42BPB',
#  'ACTN3',
#  'RPL29P12',
#  'NAP1L2',
#  'AC026410.2',
#  'FIZ1',
#  'PPIAP34',
#  'AC008770.3',
#  'CFAP100',
#  'TFPI',
#  'CTD-2201I18.1',
#  'DERL1',
#  'EFCAB10',
#  'SLC35B3',
#  'NDUFB7',
#  'MESTP3',
#  'TRPC4',
#  'EIF3J',
#  'DUSP5',
#  'MKS1',
#  'LINC01048',
#  'HACD1',
#  'TRAK2',
#  'TMEM239',
#  'GNAL',
#  'PCAT6',
#  'XRCC4',
#  'RTEL1',
#  'ATP5PDP1',
#  'MED26',
#  'AL137026.1',
#  'LINC01844',
#  'AC104237.2',
#  'CCL1',
#  'LINC02544',
#  'AC023509.6',
#  'RNY1P16',
#  'GMPR2',
#  'AL513320.1',
#  'YBX1P10',
#  'AC124319.2',
#  'LILRA5',
#  'CCT4P2',
#  'ZNF277',
#  'AC004893.1',
#  'C18orf21',
#  'YES1',
#  'KCNC1',
#  'ABCC10',
#  'RNF19A',
#  'AC091492.1',
#  'SOX9',
#  'SHANK2',
#  'ARIH2OS',
#  'LINC01356',
#  'B4GALNT1',
#  'AC010680.5',
#  'PSME2P2',
#  'AC068733.2',
#  'NSD1',
#  'HRG',
#  'PKIB',
#  'ZNF602P',
#  'RASSF2',
#  'AL157832.3',
#  'CD163L1',
#  'AC005498.1',
#  'CACNG8',
#  'AL158823.1',
#  'ABHD18',
#  'ZNF584',
#  'AC245100.2',
#  'HNRNPF',
#  'BBS7',
#  'CES1P1',
#  'AC027279.4',
#  'NEDD4',
#  'AL109628.2',
#  'PHF10',
#  'KIZ',
#  'MTND4P23',
#  'AC127164.1',
#  'CGREF1',
#  'TSTD3',
#  'CFAP157',
#  'MTCO2P12',
#  'AP002847.1',
#  'ENGASE',
#  'C3orf70',
#  'AC009948.3',
#  'OGFRP1',
#  'AC141586.5',
#  'AL049747.1',
#  'SYT13',
#  'GALR3',
#  'IFNA8',
#  'NACC1',
#  'CIAO2B',
#  'SLC20A2',
#  'AC004112.1',
#  'AC090204.1',
#  'TMEM140',
#  'AL031710.2',
#  'AL139397.2',
#  'BX322639.1',
#  'AC018754.1',
#  'AC132192.2',
#  'TBCD',
#  'AP001024.1',
#  'ING4',
#  'RSU1',
#  'ZNF529',
#  'FAM229A',
#  'AL606495.1',
#  'LUZP2',
#  'AC022364.1',
#  'AL022334.2',
#  'AC110769.1',
#  'TDRP',
#  'AC015802.5',
#  'ZNF783',
#  'FNDC7',
#  'AXDND1',
#  'PFN2',
#  'ZNF839P1',
#  'RPS3AP38',
#  'AC092794.2',
#  'AL365181.1',
#  'AC013267.1',
#  'OR5BJ1P',
#  'TIGIT',
#  'RPS5P3',
#  'FGGY',
#  'MYO15A',
#  'AC093249.4',
#  'AC020978.7',
#  'AC009237.3',
#  'UPK3B',
#  'LRRC8C',
#  'ARAP2',
#  'SAC3D1',
#  'SPDYE2',
#  'LINC01667',
#  'OGFOD1P1',
#  'GPRC5A',
#  'AC090114.3',
#  'ZNF33B',
#  'HHLA3',
#  'CTU1',
#  'FIGN',
#  'Z97055.1',
#  'BUB3',
#  'C21orf58',
#  'CCDC78',
#  'THSD1',
#  'SPTBN1',
#  'VNN1',
#  'AL354949.1',
#  'CHID1',
#  'FUT7',
#  'SDHD',
#  'ETV2',
#  'AC004801.1',
#  'AC115223.1',
#  'AC019186.1',
#  'RAMP2-AS1',
#  'AC023813.3',
#  'AL606534.2',
#  'EEF1GP4',
#  'PPIAP30',
#  'AC107302.1',
#  'FAM86KP',
#  'BRD7P4',
#  'RN7SL220P',
#  'KLF16',
#  'AC004034.1',
#  'CPAMD8',
#  'NPTXR',
#  'ATP6V0E2-AS1',
#  'AC093151.3',
#  'ARHGEF33',
#  'IRAIN',
#  'AC025171.5',
#  'AP001330.5',
#  'MRPL3P1',
#  'OR2D3',
#  'VPS13A',
#  'MTND2P28',
#  'ELL2P1',
#  'NBDY',
#  'SMAD1',
#  'AC109329.1',
#  'FBXO25',
#  'MIR218-1',
#  'AC104836.1',
#  'SIL1',
#  'POLA2',
#  'CYP2A6',
#  'AC073111.5',
#  'CCDC71L',
#  'DOCK10',
#  'AC025062.1',
#  'CHRFAM7A',
#  'PTPRN2',
#  'TEX29',
#  'ZNF433-AS1',
#  'GPM6B',
#  'AL589935.1',
#  'OR7E2P',
#  'AC016949.1',
#  'UNC5B-AS1',
#  'AC093635.1',
#  'HMGB1P27',
#  'AL157384.1',
#  'PRRT3-AS1',
#  'SLC25A32',
#  'AL356234.1',
#  'IL34',
#  'AC145676.1',
#  'MSTN',
#  'TMEM202-AS1',
#  'PES1',
#  'ANO10',
#  'PA2G4',
#  'AC034207.1',
#  'ANKRD61',
#  'TRABD',
#  'RPS4XP8',
#  'AC116049.1',
#  'DCAF16',
#  'THOC3',
#  'KLHL42',
#  'PAQR6',
#  'AC105114.2',
#  'ZNF681',
#  'HCFC1R1',
#  'LANCL1-AS1',
#  'MMP1',
#  'DBP',
#  'AC124283.4',
#  'MT1X',
#  'HIST1H2APS4',
#  'KMT2E-AS1',
#  'AC006160.1',
#  'CCDC85B',
#  'KY',
#  'SLC35G6',
#  'NHLRC1',
#  'SOD2',
#  'BCL7A',
#  'STK32B',
#  'SMC3',
#  'MON1B',
#  'CALCB',
#  'VAMP1',
#  'RAC1P6',
#  'HAGHL',
#  'FBXO34',
#  'MXD3',
#  'AC004951.4',
#  'AC005220.1',
#  'RF02271',
#  'TMEM213',
#  'PAXX',
#  'MIP',
#  'AL162456.1',
#  'AP002340.1',
#  'MRPL40P1',
#  'SETP2',
#  'AC090877.1',
#  'MTND1P23',
#  'NUP210L',
#  'AC023830.2',
#  'ATP6AP2',
#  'CNN1',
#  'FGR',
#  'GREM2',
#  'PLCD4',
#  'PPIAL4D',
#  'BOLA2P1',
#  'AC063950.1',
#  'YWHAEP5',
#  'UFC1',
#  'AC026904.3',
#  'HSD17B13',
#  'ASPHD2',
#  'AC012485.1',
#  'SMARCC1',
#  'SLC35C1',
#  'FBXO2',
#  'NALCN',
#  'SH3BGRL2',
#  'AC241584.1',
#  'AC013549.1',
#  'FAR1-IT1',
#  'INAFM1',
#  'BEND6',
#  'LETM1',
#  'AC090287.1',
#  'HNRNPA1P40',
#  'TMED8',
#  'NDUFA3',
#  'DCAF6',
#  'SLAIN2',
#  'COQ4',
#  'INPP5E',
#  'AP000695.1',
#  'BX649567.1',
#  'TNRC6A',
#  'DCAKD',
#  'AC126696.3',
#  'AC010531.6',
#  'LPAR1',
#  'ABHD12',
#  'SPRED3',
#  'AFF1',
#  'AC093227.1',
#  'ISL2',
#  'TEX46',
#  'TUBA1B',
#  'SALL4',
#  'CYP26B1',
#  'AC090543.1',
#  'AC025750.2',
#  'DALRD3',
#  'LINC01277',
#  'PCF11',
#  'AC009053.1',
#  'HPGDS',
#  'POU4F3',
#  'MT1DP',
#  'MT2A',
#  'TRPS1',
#  'TUBBP5',
#  'LMAN1',
#  'AC021205.3',
#  'ATG4A',
#  'HNRNPA3P2',
#  'MCTP1',
#  'ZDHHC7',
#  'NBPF1',
#  'FKBPL',
#  'BRIX1',
#  'MTFP1',
#  'AC005730.2',
#  'C1QL4',
#  'CIDEA',
#  'FCRLA',
#  'EEF1A1',
#  'ZNF213-AS1',
#  'AC007842.1',
#  'MT1F',
#  'AC010680.2',
#  'AC008543.3',
#  'LEXM',
#  'FES',
#  'AC025030.1',
#  'PLPP5',
#  'GYG2P1',
#  'AC093270.1',
#  'AC073326.1',
#  'PCDHGB6',
#  'EDEM2',
#  'SDHA',
#  'MAP3K15',
#  'CDH23',
#  'DDX19A',
#  'SLC4A7',
#  'PSMD9',
#  'RPL9P30',
#  'RPS15AP28',
#  'RPS19',
#  'ANKRD9',
#  'GCKR',
#  'AC103769.1',
#  'AC087072.2',
#  'TRPM3',
#  'DOCK9-DT',
#  'HS3ST2',
#  'DIMT1',
#  'UBE2D1',
#  'ZNF311',
#  'APOA1-AS',
#  'PRDM11',
#  'C9orf153',
#  'RPS11P7',
#  'GID8',
#  'HS1BP3-IT1',
#  'AC004771.1',
#  'BCLAF3',
#  'ATP5IF1',
#  'BRMS1',
#  'PTGES',
#  'AC035140.1',
#  'FBXW4',
#  'VPS39',
#  'RCHY1',
#  'AC133555.3',
#  'TBC1D8B',
#  'LTO1',
#  'PCOLCE',
#  'AP000753.2',
#  'AC023983.2',
#  'ZNF410',
#  'SLC39A3',
#  'AP003071.4',
#  'PFN4',
#  'RPS4XP18',
#  'NDUFAF4',
#  'MOCS1',
#  'PCCA-AS1',
#  'MYO1G',
#  'AL138689.1',
#  'TBC1D27P',
#  'AC020661.4',
#  'AC012313.5',
#  'RN7SL846P',
#  'FAM114A1',
#  'CNTN1',
#  'SHLD2',
#  'AC099804.1',
#  'TSSK6',
#  'ZC3HAV1',
#  'FLJ46284',
#  'AC083805.1',
#  'TIGD3',
#  'DCUN1D5',
#  'EXT2',
#  'AL050320.1',
#  'AL591806.1',
#  'JHY',
#  'AP002381.1',
#  'PYM1',
#  'AC021151.1',
#  'KLHL20',
#  'PROB1',
#  'IFI44',
#  'AL022393.1',
#  'HMG20B',
#  'RORA',
#  'RPL12P33',
#  'C7orf25',
#  'HNRNPC',
#  'APH1B',
#  'ERN1',
#  'ACCS',
#  'NDUFAF6',
#  'SPIN4',
#  'EIPR1',
#  'MRPL1',
#  'IL33',
#  'SLC12A6',
#  'AIFM2',
#  'AC027613.1',
#  'MCM8-AS1',
#  'FKBP11',
#  'RASSF8-AS1',
#  'ARHGAP42',
#  'AP001442.1',
#  'ANKRD55',
#  'PGAP2',
#  'AL078612.2',
#  'AL133517.1',
#  'AC241377.2',
#  'VEZT',
#  'AC010099.1',
#  'SV2A',
#  'RPL18P10',
#  'AL512791.2',
#  'AC104109.1',
#  'ZSCAN18',
#  'PMS2P7',
#  'AC079906.1',
#  'SVIL-AS1',
#  'DNAH7',
#  'AL451044.1',
#  'EXOSC7',
#  'AL136982.1',
#  'PGA5',
#  'MAD2L1BP',
#  'TMEM102',
#  'RNF31',
#  'AC132872.2',
#  'ST6GALNAC2',
#  'AC067751.1',
#  'AC130650.2',
#  'GPRASP2',
#  'AC004801.6',
#  'CPNE2',
#  'TET2',
#  'AC027559.1',
#  'TROAP',
#  ...}

# %%
print(len(genes1), len(genes2), len(genes1) + len(genes2))
# Out:
# 28926 28438 57364

# %%
symdiff = genes1.symmetric_difference(genes2)
symdiff
# Out:
# {'AC096708.3',
#  'AC005021.1',
#  'AL031595.1',
#  'AC067852.2',
#  'AL356585.3',
#  'CARD11',
#  'AC004540.1',
#  'HNRNPA3P14',
#  'AL365203.1',
#  'RPS12P24',
#  'AC064871.1',
#  'IGLON5',
#  'AL451139.1',
#  'AC008592.5',
#  'AL031281.1',
#  'SNORA74B',
#  'SERPINA1',
#  'AC012146.2',
#  'ACSBG2',
#  'AC117503.3',
#  'ZNHIT1P1',
#  'Z97985.1',
#  'AC087879.1',
#  'AP005901.4',
#  'AP003717.3',
#  'Z98749.1',
#  'FER1L6-AS1',
#  'SEC14L4',
#  'LINC01102',
#  'AC022325.1',
#  'LYPLA1P3',
#  'RNA5SP193',
#  'SOCS5P2',
#  'AC133961.1',
#  'AC008556.1',
#  'BX539320.1',
#  'AL158212.4',
#  'CTAGE12P',
#  'AC010478.1',
#  'AL353706.1',
#  'AL049646.1',
#  'MLLT10P1',
#  'AC011442.1',
#  'TAS2R6P',
#  'NAT16',
#  'AL513190.1',
#  'AC139491.5',
#  'COL20A1',
#  'AC012486.1',
#  'AC005304.2',
#  'AC004771.2',
#  'AC090709.1',
#  'AC016583.1',
#  'SPECC1L-ADORA2A',
#  'KRT8P8',
#  'EEF1A1P31',
#  'RPL17P2',
#  'AC240565.2',
#  'AC099811.3',
#  'RN7SL629P',
#  'PCDHGC5',
#  'LDLRAD4-AS1',
#  'CELF3',
#  'AL137002.2',
#  'FCN3',
#  'GIMAP2',
#  'LINC02284',
#  'ST14',
#  'AL121900.1',
#  'AC245452.2',
#  'AL512649.1',
#  'AC073465.1',
#  'AC107980.1',
#  'AC091544.4',
#  'EFL1P1',
#  'AL591767.3',
#  'AC111200.1',
#  'AP003086.2',
#  'AC124293.1',
#  'AC109630.1',
#  'AC004816.1',
#  'TBC1D29',
#  'AC099550.1',
#  'AC129510.1',
#  'LINC02060',
#  'AC063965.1',
#  'OR52B6',
#  'AC022960.1',
#  'ITGAD',
#  'TUBB8P7',
#  'AL627309.4',
#  'MYL12BP2',
#  'SCN5A',
#  'AC239802.1',
#  'CTAGE16P',
#  'CBX3P1',
#  'AL022097.1',
#  'AL133241.1',
#  'OR9K1P',
#  'PLGLA',
#  'LRG1',
#  'RN7SL754P',
#  'FLJ34503',
#  'AC018755.1',
#  'RPL22P5',
#  'TAS2R1',
#  'RN7SKP240',
#  'HAO1',
#  'AJ003147.1',
#  'FAM84A',
#  'RN7SL89P',
#  'GPR87',
#  'LINC01262',
#  'PCDHA12',
#  'AC126335.1',
#  'AC012625.1',
#  'LIME1',
#  'SFTPC',
#  'BOLA2-SMG1P6',
#  'GOLGA2P3Y',
#  'RPL12P43',
#  'UBE2CP1',
#  'AC145423.2',
#  'HMGB3P5',
#  'AC073082.1',
#  'AC008073.2',
#  'AL365330.1',
#  'AC104623.2',
#  'AC090340.1',
#  'SMURF2P1',
#  'AC243571.2',
#  'AC106881.1',
#  'AC009264.1',
#  'PLCXD3',
#  'RNU6-1301P',
#  'JPH1',
#  'RN7SL801P',
#  'AL499616.1',
#  'AL118505.1',
#  'LINC02530',
#  'AC099654.2',
#  'SPRR2G',
#  'BZW1P1',
#  'SST',
#  'PCAT14',
#  'PRICKLE2-AS1',
#  'CTRB2',
#  'AC015726.3',
#  'AC007342.3',
#  'RN7SL459P',
#  'LINC01209',
#  'SYCE1',
#  'AL121809.2',
#  'LNCOC1',
#  'HSFX3',
#  'AL034349.1',
#  'FOXA3',
#  'PRAMEF14',
#  'AC068205.1',
#  'SMIM15-AS1',
#  'RPL17P3',
#  'MT-TL2',
#  'AC016868.1',
#  'AL163953.1',
#  'ONECUT3',
#  'AC114755.2',
#  'RNU6-686P',
#  'HCAR3',
#  'AC009054.1',
#  'AC010409.1',
#  'AC087163.1',
#  'RNU4-1',
#  'AC093214.1',
#  'AC011444.3',
#  'TRIM17',
#  'AL079342.2',
#  'NPFFR2',
#  'RNU6-589P',
#  'ATP5PBP5',
#  'OR10G3',
#  'NPHP3-ACAD11',
#  'TRIM53BP',
#  'SNORA14A',
#  'AL137792.1',
#  'SPATA13-AS1',
#  'AC005392.1',
#  'IFNG-AS1',
#  'USP43',
#  'COLCA2',
#  'AC127455.1',
#  'ENPP7P7',
#  'NAP1L2',
#  'AC013404.1',
#  'EPS8L3',
#  'AC008770.3',
#  'CFAP100',
#  'AC138123.1',
#  'CYCSP28',
#  'MESTP3',
#  'TMEM239',
#  'AC103702.2',
#  'SV2C',
#  'AC104237.2',
#  'CCDC179',
#  'AC090666.1',
#  'LILRA5',
#  'AL031670.1',
#  'ENPEP',
#  'AL138889.1',
#  'AC131391.1',
#  'AC005865.1',
#  'LINC01338',
#  'RIT2',
#  'HRG',
#  'LINC02234',
#  'IPCEF1',
#  'AC004900.1',
#  'PGAM1P7',
#  'BATF',
#  'VDAC1P3',
#  'AL645608.8',
#  'RPL23AP17',
#  'MRPL35P4',
#  'MTND4P23',
#  'ADGRE1',
#  'TLX2',
#  'H2AFB2',
#  'AC092447.5',
#  'AL049747.1',
#  'SYT13',
#  'IFNA8',
#  'AC092296.2',
#  'SETP10',
#  'AL139397.2',
#  'AL355990.2',
#  'RN7SL331P',
#  'PRAMEF12',
#  'AL360175.1',
#  'AL022334.2',
#  'AC110769.1',
#  'AC026471.5',
#  'AC091614.1',
#  'AC016772.1',
#  'AC009955.4',
#  'AC026956.1',
#  'C1QL2',
#  'LINC01667',
#  'TPT1P13',
#  'AC104634.1',
#  'AC099670.3',
#  'RN7SL146P',
#  'SNTN',
#  'FUT7',
#  'AL691515.1',
#  'AC005176.1',
#  'AC106900.1',
#  'AL606763.1',
#  'AC004034.1',
#  'AL512656.1',
#  'CKS1BP2',
#  'NIP7P3',
#  'AC009495.3',
#  'AC109329.1',
#  'AL391095.3',
#  'LINC01054',
#  'CDC37P2',
#  'LINC02598',
#  'AL450163.1',
#  'AP004247.2',
#  'AC122713.1',
#  'DEFB109F',
#  'RPL39P25',
#  'LMOD2',
#  'SNRPCP10',
#  'MROH2B',
#  'HIST1H2APS4',
#  'AL451107.1',
#  'OR10AH1P',
#  'AC104532.2',
#  'LINC02130',
#  'ADAM30',
#  'AC107959.3',
#  'MTHFD2P6',
#  'RAC1P6',
#  'AL513412.1',
#  'TMEM213',
#  'AL162456.1',
#  'AP002340.1',
#  'AL357075.1',
#  'AC023830.2',
#  'FGR',
#  'BOLA2P1',
#  'PRAMEF5',
#  'SLC9A4',
#  'AL033530.1',
#  'AC012485.1',
#  'RN7SL748P',
#  'LINC00989',
#  'RNU6-310P',
#  'RN7SL127P',
#  'IQSEC3',
#  'LINC02526',
#  'BX649567.1',
#  'MBD3L2B',
#  'HNRNPABP1',
#  'AC007849.1',
#  'Z84484.1',
#  'HSPE1P28',
#  'AC011503.1',
#  'AC073896.5',
#  'STXBP5L',
#  'CIDEA',
#  'AC090453.1',
#  'HTR1DP1',
#  'AC011195.2',
#  'AL132996.1',
#  'MPPED2',
#  'AC025030.1',
#  'A4GNT',
#  'LINC01997',
#  'AC073326.1',
#  'ADH5P3',
#  'AP003096.1',
#  'SMIM2',
#  'AC018755.4',
#  'ALG13-AS1',
#  'CT45A3',
#  'AC007907.1',
#  'CCNI2',
#  'AC093766.1',
#  'AC005845.1',
#  'AF279873.4',
#  'PCCA-AS1',
#  'AL645608.3',
#  'TBC1D27P',
#  'GOLGA8G',
#  'AC013549.2',
#  'AC090515.3',
#  'LINC01894',
#  'AL050320.1',
#  'AL591806.1',
#  'AC021151.1',
#  'RNA5SP530',
#  'GLULP4',
#  'AC106028.4',
#  'AC022748.3',
#  'INSL3',
#  'AL161938.1',
#  'AC027613.1',
#  'MCM8-AS1',
#  'AC008667.3',
#  'AL121832.3',
#  'RSPO1',
#  'AC010099.1',
#  'RPS3AP40',
#  'RN7SL672P',
#  'LINC02507',
#  'LY6H',
#  'AC104109.1',
#  'AC008464.1',
#  'AL389885.1',
#  'OR10AB1P',
#  'AC079598.1',
#  'AC012470.1',
#  'ARIH2P1',
#  'AL591686.1',
#  'LINC02000',
#  'AC005529.1',
#  'BEND4',
#  'RIMBP3',
#  'IFITM8P',
#  'AMER3',
#  'NKD1',
#  'AC136618.2',
#  'AC134682.1',
#  'SYF2P2',
#  'RNU6-702P',
#  'SNORA74A',
#  'AL132640.1',
#  'OR2K2',
#  'TMEM95',
#  'TTC39DP',
#  'Z83851.2',
#  'AC107909.2',
#  'ARX',
#  'MYH14',
#  'LINC01555',
#  'AL096678.1',
#  'CDRT15P1',
#  'TXNP3',
#  'AL354707.2',
#  'LINC00434',
#  'AC025569.1',
#  'USP12PX',
#  'KRBOX1-AS1',
#  'AL109806.1',
#  'MYO1H',
#  'FP236240.3',
#  'TRIM64B',
#  'KRT17P4',
#  'AP002993.1',
#  'VPS35P1',
#  'AC087632.1',
#  'AC114812.3',
#  'AC017074.1',
#  'LINC00845',
#  'AC002310.3',
#  'AL158209.1',
#  'AL355989.1',
#  'MTND5P15',
#  'ALG1L13P',
#  'RN7SL395P',
#  'AC025287.4',
#  'KIAA1614-AS1',
#  'AC092447.10',
#  'AC021755.2',
#  'AL512306.1',
#  'AC080079.1',
#  'LINC00534',
#  'PSG9',
#  'AC004941.1',
#  'AC013244.3',
#  'C8orf49',
#  'AC007342.9',
#  'LINC01918',
#  'RNU6-790P',
#  'CD5',
#  'TOMM22P2',
#  'AC012511.1',
#  'AL589743.2',
#  'C2orf48',
#  'RNU4-86P',
#  'SMIM23',
#  'AL121782.1',
#  'AL391807.1',
#  'AL353748.1',
#  'PRAMEF20',
#  'RLN2',
#  'TRIM51GP',
#  'RNU6-1000P',
#  'AP001476.2',
#  'LINC01823',
#  'AC099786.3',
#  'RPSAP10',
#  'RPL12P9',
#  'GRIK3',
#  'SLC6A11',
#  'RPL23AP83',
#  'AC079776.1',
#  'AC092681.3',
#  'MTCO3P29',
#  'ISCA2P1',
#  'SLC38A8',
#  'AC090502.4',
#  'AC116158.2',
#  'PSAT1P4',
#  'FCGR2B',
#  'KDM4E',
#  'BX322635.1',
#  'BX842568.4',
#  'AL031597.1',
#  'AL096712.1',
#  'AC027601.1',
#  'TRIM49D2',
#  'PSAT1P1',
#  'DUSP5P1',
#  'SUMO1P2',
#  'SUMO2P15',
#  'OR2A1-AS1',
#  'HSP90AB6P',
#  'OPN5',
#  'YY1P1',
#  'AC024267.5',
#  'SNRPEP3',
#  'SLC25A5P3',
#  'AC018761.3',
#  'RPL7L1P3',
#  'IMMP1LP2',
#  'AC007395.1',
#  'SHANK2-AS3',
#  'AC005832.1',
#  'RPL31P50',
#  'RN7SL105P',
#  'IL10',
#  'CMTM5',
#  'AC073359.1',
#  'AP005131.2',
#  'AP000462.1',
#  'KRT8P26',
#  'ADAM29',
#  'AL591926.8',
#  'AC098847.1',
#  'MTUS2-AS1',
#  'AL023284.2',
#  'LINC01180',
#  'NCR3',
#  'AC097639.1',
#  'AK6P2',
#  'SMAD1-AS2',
#  'SLC25A51P1',
#  'AC239600.2',
#  'AC103987.2',
#  'CMA1',
#  'NARF-AS1',
#  'AP002884.2',
#  'KIF12',
#  'AC021739.2',
#  'AL589674.1',
#  'MTND2P12',
#  'TUSC7',
#  'AC069282.1',
#  'TVP23CP2',
#  'AC092047.1',
#  'AL138976.1',
#  'AL357078.2',
#  'AC008737.3',
#  'LINC02515',
#  'AC138473.1',
#  'PRODH',
#  'AC009967.1',
#  'AC020978.4',
#  'AC009237.10',
#  'AL139158.1',
#  'PRAMEF11',
#  'YBX1P7',
#  'AL356275.2',
#  'AL356311.1',
#  'HSPD1P3',
#  'ACTBP13',
#  'OGFR-AS1',
#  'RPS29P20',
#  'RDH10-AS1',
#  'RNU6-729P',
#  'DMRT3',
#  'AC124916.2',
#  'RPL21P38',
#  'SNRPEP6',
#  'RN7SL789P',
#  'RN7SL43P',
#  'SERPINA12',
#  'C8orf59P1',
#  'FAM90A28P',
#  'SNORA80D',
#  'AC023824.5',
#  'EGLN3P1',
#  'PRSS16',
#  'RPS12P2',
#  'AL161757.1',
#  'AC090971.5',
#  'PRKAR1AP1',
#  'GPAT2',
#  'RPL13AP17',
#  'AC007406.3',
#  'DCDC2C',
#  'AC090517.1',
#  'ABHD17AP8',
#  'AC027176.2',
#  'AC005840.3',
#  'AC090921.1',
#  'AC096638.1',
#  'AC011990.1',
#  'AC009452.1',
#  'AC023310.4',
#  'AC019072.1',
#  'IL36G',
#  'AL356320.1',
#  'AL592463.1',
#  'RN7SL160P',
#  'OR2F2',
#  'ARL13A',
#  'SUMO2P20',
#  'RN7SL787P',
#  'ACSM4',
#  'AC012441.1',
#  'RAET1K',
#  'HSP90AB7P',
#  'AP000892.1',
#  'AC093702.1',
#  'SNRPCP14',
#  'AL357563.1',
#  'RNU2-51P',
#  'LINC02241',
#  'GLYATL1P2',
#  'AC068594.1',
#  'LINC02582',
#  'AC002545.1',
#  'AL512413.1',
#  'AC139792.3',
#  'XCL1',
#  'AL158064.1',
#  'SSU72P8',
#  'AC091987.1',
#  'AL356270.1',
#  'AL590666.4',
#  'AC129492.2',
#  'AD000671.3',
#  'LINC00370',
#  'PRR23C',
#  'AC008897.2',
#  'MTUS2-AS2',
#  'AL603865.1',
#  'SLC36A3',
#  'AC092447.1',
#  'AL137220.1',
#  'MEF2B',
#  'CLRN1-AS1',
#  'AC108059.1',
#  'AC012313.6',
#  'CR848007.1',
#  'AC011450.1',
#  'AC092979.1',
#  'AL359258.1',
#  'MTND3P25',
#  'AL161725.2',
#  'RPL29P22',
#  'AC026782.2',
#  'LINC00865',
#  'PNLIPRP3',
#  'AC114947.1',
#  'AC007216.1',
#  'ST13P20',
#  'AL445991.1',
#  'AC097372.1',
#  'AC008434.1',
#  'LNCARSR',
#  'Z93022.1',
#  'LINC01214',
#  'AL033384.1',
#  'LINC00336',
#  'AC121320.1',
#  'LUNAR1',
#  'LINC00703',
#  'AC005730.1',
#  'ADORA2BP1',
#  'KRT73-AS1',
#  'SFTA2',
#  'AC006435.4',
#  'AL357315.2',
#  'DOC2B',
#  'LINC01902',
#  'AC025754.1',
#  'PANX3',
#  'TRIM48',
#  'RAG2',
#  'RN7SL403P',
#  'BRS3',
#  'AF038458.1',
#  'HNRNPA1P13',
#  'OR52P1P',
#  'RN7SL503P',
#  'LGALS9C',
#  'MTND4P14',
#  'AP002992.1',
#  'GJB2',
#  'AC005972.2',
#  'LINC01518',
#  'AC090907.1',
#  'LINC02468',
#  'AC092868.3',
#  'AC011247.3',
#  'PLIN5',
#  'SCARNA1',
#  'AC007920.1',
#  'AC110058.1',
#  'Z95114.3',
#  'RN7SL442P',
#  'AC007601.1',
#  'AC022558.3',
#  'AL133297.2',
#  'PRND',
#  'AC083829.1',
#  'EPHA6',
#  'RNU1-3',
#  'AL157791.2',
#  'LINC01817',
#  'ARHGAP8',
#  'GSG1L',
#  'AP000477.1',
#  'ELN-AS1',
#  'MIR4527HG',
#  'AC066613.1',
#  'LINC02109',
#  'AC007527.1',
#  'RN7SL649P',
#  'LYZ',
#  'AL357033.4',
#  'CALN1',
#  'AC025263.3',
#  'TAL1',
#  'TAS2R8',
#  'AP001048.1',
#  'ANO2',
#  'AC078820.1',
#  'RBPJP5',
#  'MGAM',
#  'AL352979.3',
#  'RPL21P50',
#  'AC124893.1',
#  'ST8SIA6',
#  'TMEM215',
#  'RSPH6A',
#  'AL162253.1',
#  'ERMN',
#  'METTL21C',
#  'ANKRD30A',
#  'GNG5P1',
#  'CBX3P7',
#  'AC087499.2',
#  'AC093166.1',
#  'AP003557.1',
#  'FRMPD2B',
#  'LINC01842',
#  'AP000525.1',
#  'AP002833.3',
#  'LINC00538',
#  'MIR3945HG',
#  'CTAG2',
#  'CALM2P1',
#  'AC215522.2',
#  'AL078621.2',
#  'AC112492.5',
#  'FIGNL2',
#  'AC063923.2',
#  'AC093249.3',
#  'AC008738.2',
#  'LINC01304',
#  'ACTG1P9',
#  'AL365205.1',
#  'AL031432.5',
#  'AC108751.4',
#  'IL18RAP',
#  'AL391883.1',
#  'CFL1P4',
#  'CATSPERB',
#  'ANKRD20A2',
#  'AC068135.2',
#  'AC025881.1',
#  'AC087623.1',
#  'ITM2BP1',
#  'FANK1-AS1',
#  'EOMES',
#  'LINC00861',
#  'TMEM52B',
#  'AMD1P3',
#  'ITK',
#  'NREP-AS1',
#  'AC246785.2',
#  'KRTAP9-6',
#  'RN7SKP285',
#  'AL023803.3',
#  'AC239860.2',
#  'AC092068.3',
#  'RNU6-130P',
#  'GPR83',
#  'NOS1',
#  'AC084030.1',
#  'RAD17P1',
#  'THEMIS',
#  'LINC01513',
#  'AC091868.1',
#  'AC079600.1',
#  'USF1P1',
#  'AP003119.1',
#  'BBOX1',
#  'TLX1',
#  'ZBP1',
#  'CCNYL2',
#  'C2CD4A',
#  'AL049840.3',
#  'GPR12',
#  'AC097521.1',
#  'TPO',
#  'AC025917.1',
#  'RN7SL688P',
#  'PTAFR',
#  'AC009127.2',
#  'LINC01206',
#  'AL358215.2',
#  'AC073288.2',
#  'LINC02111',
#  'BEST2',
#  'AC127496.3',
#  'NTAN1P3',
#  'LRRC37A13P',
#  'CD209',
#  'CCDC58P2',
#  'AL390774.1',
#  'AC023206.1',
#  'GSDMC',
#  'AC138123.2',
#  'EIF4BP5',
#  'INHBC',
#  'GAS2L1P2',
#  'BHMG1',
#  'AL355355.2',
#  'HMGB3P14',
#  'AC079841.1',
#  'LINC02128',
#  'LINC01484',
#  'DNAJB3',
#  'CERNA2',
#  'HCG4B',
#  'AC004921.1',
#  'AL079307.1',
#  'RNU6-625P',
#  'AC004706.1',
#  'API5P2',
#  'RPL39P6',
#  'AC136624.1',
#  'LRRC37A15P',
#  'OR55B1P',
#  'AL589826.2',
#  'AP004289.1',
#  'TLL1',
#  'LINC02251',
#  'AL121839.1',
#  'RNU6-313P',
#  'SULT6B1',
#  'RPL17P20',
#  'OR5P1P',
#  'RN7SL388P',
#  'RN7SL268P',
#  'AL138799.4',
#  'AC004890.3',
#  'USP12-AS1',
#  'AP003471.1',
#  'AC021146.1',
#  'POLD2P1',
#  'AC079296.1',
#  'AL138775.1',
#  'AC092364.1',
#  'LINC01210',
#  'AC010547.4',
#  'SIRPAP1',
#  'LSM6P2',
#  'KLF17P1',
#  'EVX2',
#  'SEPT4-AS1',
#  'AC073370.1',
#  'AL390318.1',
#  'LINC00637',
#  'AL080276.1',
#  'RNU6ATAC7P',
#  'ARMC8P1',
#  'AC016769.2',
#  'POU3F4',
#  'AC011239.2',
#  'TRIM10',
#  'ACTL7B',
#  'ZNF503-AS1',
#  'GRM5',
#  'MLIP-AS1',
#  'AC084879.1',
#  'RN7SL615P',
#  'CDC14C',
#  'MCM2',
#  'AL450336.1',
#  'AC009121.2',
#  'STPG4',
#  'NPM1P33',
#  'CD164L2',
#  'C1orf210',
#  'RPL35AP26',
#  'FAM166A',
#  'AC005180.1',
#  'CPA6',
#  'AC011005.4',
#  'C4B-AS1',
#  'AC007608.4',
#  'AC098824.1',
#  'VPS13A-AS1',
#  'AC013270.1',
#  'LRRC8E',
#  'AC012508.2',
#  'SNRPCP4',
#  'AC007690.1',
#  'AC022167.4',
#  'AC116158.1',
#  'RNU6-12P',
#  'TAS2R46',
#  'AL133480.1',
#  'OR7E157P',
#  'NOP56P3',
#  'AL078599.2',
#  'AL353795.1',
#  'LINC02024',
#  'ARSFP1',
#  'DGKB',
#  'SEPT3',
#  'AP002754.1',
#  'GRAP2',
#  'AL359844.1',
#  'HSPA8P14',
#  'ZNF541',
#  'AL133523.1',
#  'AC079921.1',
#  'DKK4',
#  'AL049552.1',
#  'FABP5P15',
#  'AC073111.1',
#  'AC119751.3',
#  'HNRNPA1P44',
#  'ABO',
#  'AC012254.4',
#  'AL354872.1',
#  'RNA5SP370',
#  'KRT18P67',
#  'GPR151',
#  'CERS3-AS1',
#  'PPP2R2C',
#  'RN7SL101P',
#  'APOBEC3B',
#  'LINC02377',
#  'AC069294.1',
#  'TMEM72',
#  'RN7SL262P',
#  'PGA4',
#  'LRTM1',
#  'FGF12',
#  'NODAL',
#  'AMHR2',
#  'CCNQP1',
#  'AC022784.5',
#  'AP000533.2',
#  'LINC01366',
#  'AC103691.1',
#  'AC097460.2',
#  'IYD',
#  'DYDC2',
#  'AC016396.2',
#  'FCGR2C',
#  'PHBP15',
#  'KLK13',
#  'CENPUP1',
#  'MTCO1P55',
#  'PRICKLE4',
#  'AL592431.2',
#  'AC080013.2',
#  'RN7SKP219',
#  'RN7SKP154',
#  'AC091231.1',
#  'AL031056.2',
#  'C1orf226',
#  'PRELID1P3',
#  'AP001180.4',
#  'AQP8',
#  'AC011294.1',
#  'LEMD1-AS1',
#  'HNRNPA1P28',
#  'CUX2',
#  'SHC1P1',
#  'AL512631.1',
#  'LINC01655',
#  'EXD1',
#  'AP002761.2',
#  'FDPSP3',
#  'RN7SL375P',
#  'AC083862.1',
#  'AC063979.2',
#  'AC011466.3',
#  'ATP5MC1P8',
#  'SLCO1C1',
#  'OR2B11',
#  'AC093821.1',
#  'AL136452.1',
#  'AC012676.2',
#  'AC004836.1',
#  'ASNSP4',
#  'AC007533.1',
#  'AC115283.1',
#  'AC079780.1',
#  'DMRTA2',
#  'RNU6-653P',
#  'AC092720.1',
#  'AP003086.3',
#  'AC084757.4',
#  'AL732414.1',
#  'RPS3AP30',
#  'KF455155.1',
#  'AC010240.1',
#  'RPL23AP69',
#  'PPP1R14BP2',
#  'AC020549.1',
#  'TMEM176B',
#  'CA8',
#  'AC110998.1',
#  'MUC20P1',
#  'HS6ST2-AS1',
#  'SOST',
#  'ZPBP2',
#  'AC093206.1',
#  'FAM181A-AS1',
#  'AL391646.1',
#  'THRAP3P1',
#  'TMEM110-MUSTN1',
#  'MTND4LP9',
#  'RN7SL804P',
#  'PPIAP51',
#  'AC026786.2',
#  'ALG1L6P',
#  ...}

# %%
len(symdiff)
# Out:
# 5418

# %% [markdown]
# # Loading barcodes
#
# Create a function to load barcode data from the dimension 2 CSV file. It is of the format:
#
#     "3","AACCGTAATCGGGACCATCATCCC"
#
# where `3` is a strictly increasing cell ID as found in the count matrix, and `AACCGTAATCGGGACCATCATCCC` is the full barcode according to this data set.
#
# Whenever a barcode is encountered, we check if its last 16 nt's have been found in the Cell Ranger barcode set.
#
# This returns a list whose `n`th element corresponds to the barcode of the cell with the corresponding ID, or `None` if the cell ID's barcode is not found in the Cell Ranger barcode set.

# %%
def load_barcodes(batch, variant, good_barcodes):
    result = []
    barcode_path = "source/{}_{}_dim2.csv".format(batch, variant)  
    
    with open(barcode_path, "r") as barcodes:
        # Skip R crap in first line.
        next(barcodes)
        
        for i, line in enumerate(barcodes):
            cell_id, full_barcode = line.rstrip().replace('"', '').split(",")
            barcode = full_barcode[-16:]
            cell_id = int(cell_id)
            
            # The cell IDs should be continuous.
            assert cell_id == (i + 1)
            
            if barcode not in good_barcodes:
                result.append(None)
            elif good_barcodes[barcode] != int(batch[-1]):
                result.append(None)
                #print("ERROR:", barcode, "is in good set but corresponds to batch", good_barcodes[barcode])
            else:
                result.append(barcode)
    
    return result

# %% [markdown]
# As an experiment, create a histogram to see how many cell IDs appear per cellular barcode. We can see that all of them except one have 4 cell IDs corresponding to a barcode, the rest of the barcode is the sample barcode.

# %%
"""
barcodes = load_barcodes("S1", "exon", pawel_barcodes)
histogram = defaultdict(int)

for barcode in barcodes:
    if barcode:
        histogram[barcode] += 1

histogram
"""
# Out:
# '\nbarcodes = load_barcodes("S1", "exon", pawel_barcodes)\nhistogram = defaultdict(int)\n\nfor barcode in barcodes:\n    if barcode:\n        histogram[barcode] += 1\n\nhistogram\n'

# %% [markdown]
# # Loading transcript count matrix
#
# The count matrix is of the format:
#
#     %
#     no_genes no_cells no_counts
#     19 1 1
#     34 1 1
#     [...]
#     33663 12318 1
#     33665 12318 35
#     33678 12318 1
#
# where the first number represents the gene, the second number represents the cell, and the third number represents the count.
#
# We then get a `cells` by `genes` count matrix indexed by the cell IDs and gene IDs as described above.

# %%
def load_transcript_matrix(batch, variant, genes, barcodes):
    matrix_path = "source/{}_{}.mmf".format(batch, variant)
    
    matrix = None
    
    with open(matrix_path, "r") as f:
        first_line = True
        
        for line in f:
            if "%" in line:
                continue
            
            gene, cell, count = [int(i) for i in line.rstrip().split()]
            
            if first_line:
                assert gene == len(genes)
                assert cell == len(barcodes)
                
                first_line = False
                matrix = np.ndarray(shape=(cell, gene), dtype=np.dtype(np.int16))
                continue
            
            
            gene_pos = gene - 1
            cell_pos = cell - 1
            
            matrix[cell_pos, gene_pos] = count
    
    return matrix

# %% [markdown]
# # Create Pandas DataFrame from count matrix
#
# Given a count matrix of size `genes x cells`, a list of length `genes` and a list of length `cells`, create a Pandas DataFrame with index `cells` and column labels from `genes`.
#
# As we have seen from the barcode loading function, we will have four rows in our table corresponding to the same barcode, and some of the data we get from the matrix does not correspond to a barcode in the Cell Ranger set. During this process, we will filter out all rows that do not have a valid Pawel barcode (i.e. index is None), and group and sum all (4) rows that have the same barcode.

# %%
def dataframe_from_matrix(m, genes, barcodes):
    assert m.shape == (len(barcodes), len(genes))
    
    # Create a data frame from the count matrix, keyed by the barcode
    # and gene annotations we created.
    result = pandas.DataFrame(m)
    result.index = barcodes
    result.columns = genes
    
    # First, get rid of all the rows whose barcode is None. This means those
    # cells were not found in the reference barcode set.
    result = result[result.index.notnull()]
    
    # Then, since each barcode appears to correspond to four cell IDs,
    # we get counts spread out across these four IDs. Let's collapse the duplicates.
    result = result.groupby(by=lambda x: x).sum()
    
    return result

# %% [markdown]
# # Construct DataFrame
#
# Given a batch identifier list (i.e. `["S1", "S2"]`) and matrix name list (i.e. `["exon", "intron"]`), create a Pandas DataFrame from the corresponding count matrices and gene/cell dimension file for each. In addition, update a set `genes_set` with all genes that have been encountered in this count matrix, as these are not normalized by default across matrices in a batch (unlike cell IDs).

# %%
def construct_dataframes(batches, matrices, genes_set):
    for batch_name in batches:    
        prev_barcodes = None

        for matrix_name in matrices:
            print("Now processing", batch_name, matrix_name)

            genes = load_genes(batch_name, matrix_name)        
            print("Genes list loaded at", len(genes), "items.")

            barcodes = load_barcodes(batch_name, matrix_name, pawel_barcodes)
            print("Barcodes list loaded at", len(barcodes), "items.")

            print("Loading transcription matrix and converting to dataframe...")
            m = load_transcript_matrix(batch_name, matrix_name, genes, barcodes)
            m = dataframe_from_matrix(m, genes, barcodes)

            genes_set.update(m.columns)
            print("Total gene set is now", len(genes_set), "long.")

            if prev_barcodes is not None:
                assert m.index.equals(prev_barcodes)
            else:
                prev_barcodes = m.index
            
            # TODO REMOVE THIS
            return m

            m.to_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))
            print("Count matrix with dimensions", m.shape, "created and pickled for", batch_name, matrix_name)
            print("")

        print("")

# %% [markdown]
# # Sorting genes in DataFrames
#
# Given a batch identifier list (i.e. `["S1", "S2"]`) and matrix name list (i.e. `["exon", "intron"]`), load the corresponding DataFrames. Take the `genes_set` generated from the previous process and add to each dataframe the genes that are not encountered in that count matrix, and the counts to 0 for all cells. This is needed as all count matrices need to be the same dimension when the AnnData layers are generated. To normalize the list of genes, we will sort the columns alphabetically as well.

# %%
def normalize_dataframe_genes(batches, matrices, genes_set):
    print("Normalizing dimensions of count matrices along genes...")

    for batch_name in batches:    
        for matrix_name in matrices:
            m = pandas.read_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))

            print("Old shape of", batch_name, matrix_name, "was", m.shape)
            missing_genes = genes_set - set(m.columns)
            for missing_gene in missing_genes:
                m[missing_gene] = 0
            print("New shape is", m.shape)

            print("Reordering genes in alphabetical order...")
            print("Old column order was", m.columns)
            m = m.reindex(sorted(m.columns), axis=1)
            print("New column order is", m.columns)

            m.to_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))
            print("Normalized count matrix for", batch_name, matrix_name, "pickled.")
            print("")

        print("")

# %% [markdown]
# # Create layered AnnData object from batch matrices
#
# Create a layered AnnData object from frames for each individual batch. In practice, this takes all frames with names in a matrix list (i.e. `["intron", "exon", "spanning"]`) for each batch (i.e. `["S1", "S2"]`), and creates a layered AnnData object with layer names corresponding to `layer_names` (i.e. `["unspliced", "spliced", "ambiguous"]`) from these frames.
#
# Frames should have identical dimensions, indices and column names for this to work.
#
# The layer with name `spliced` is implicitly used as the main count matrix of the AnnData object.

# %%
def create_anndata_from_frames(batches, matrices, layer_names):
    results = []
    
    for batch in batches:
        result = None
        print("Now processing batch", batch, "...")
        
        for matrix, layer in zip(matrices, layer_names):
            print("Loading matrix", matrix, "...")
            m = pandas.read_pickle("/tmp/{}_{}.pickle".format(batch, matrix))
            
            if not result:
                print("Creating AnnData object...")
                
                result = anndata.AnnData(shape=m.shape)
                result.obs = pandas.DataFrame({"cellular_barcode": list(m.index)})
                result.var = pandas.DataFrame({"gene_names": list(m.columns)})
                
            if layer == "spliced":
                print("Layer is", layer, ", adding it as main count matrix to object...")
                result.X = m
            
            print("Adding count matrix as layer", layer, "to AnnData object...")
            result.layers[layer] = m.values
            print("")

        result.var_names = [gene for gene in result.var["gene_names"]]
        result.obs_names = [barcode for barcode in result.obs["cellular_barcode"]]
        result.obs_names_make_unique()
        results.append(result)
                
        print("Final AnnData object is", result)
        
        print("Saving layered AnnData object for batch", batch, "...")
        result.write("./write/{}-final.h5ad".format(batch))
        print("")

# %% [markdown]
# # Merge AnnData objects along batches
#
# Given a list of AnnData objects corresponding to each batch, create one large AnnData object comprising all batches. Save merged AnnData object for future processing.

# %%
def create_merged_anndata(batches):
    result = None
    to_merge = []
    
    for batch in batches:
        if not result:
            print("Merged AnnData file not yet created, making it from batch", batch)
            result = anndata.read_h5ad("./write/{}-final.h5ad".format(batch))
            print("Merged AnnData file is now", result)
        else:
            print("Loading batch", batch)
            curr = anndata.read_h5ad("./write/{}-final.h5ad".format(batch), backed="r+")
            print("Loaded AnnData file is", curr, ", appending to list of objects to concatenate...")
            to_merge.append(curr)
        print("")
    
    print("")        
    print("Concatenating list", to_merge, "to original file")
    result = result.concatenate(*to_merge, batch_categories=batches, index_unique=None)
    print("Concatenated AnnData object is", result, ", saving it to disk...")
    result.write("./write/merged-final.h5ad")

# %% [markdown]
# # Run the procedures above
# Create the variables for this experiment and run the procedures above, creating an AnnData matrix used in future notebooks.

# %%
batches = ('S1', 'S2')
matrices = ('exon', 'intron', 'spanning')
layer_names = ('spliced', 'unspliced', 'ambiguous')
all_genes = set()

# %%
m = construct_dataframes(batches, matrices, all_genes)
# Out:
# Now processing S1 exon
# Genes list loaded at 28926 items.
# Barcodes list loaded at 26709 items.
# Loading transcription matrix and converting to dataframe...
# Total gene set is now 28926 long.

# %%
m
# Out:
#                   MT-CO1  RPL10  MORF4L2  TMSB4X  RPL3  PDXK  MYL9  EIF2S2  \
# AAACCTGAGACATAAC     135    117        2     257    59     1     2      10
# AAACCTGAGAGTAAGG     153    313       10     284   151     2    12       8
# AAACCTGAGATCCCAT      94    244        2      83    90     0     8       1
# AAACCTGCAAGCCGCT     112    263        1     123   126     0    10       4
# AAACCTGCAATTGCTG     151    236        8     178   109     3    12       4
# AAACCTGCACGGTAAG     227    350        5     322   155     4     5       4
# AAACCTGGTAGCAAAT     163     72        5     284    16     0     2       6
# AAACCTGGTAGGCTGA      76    180        3     145    88     0    10       4
# AAACCTGGTCAGGACA      63    230        2     148    85     0    21       3
# AAACCTGGTCTCAACA      66    169        0      56    71     0     4       5
# AAACCTGTCAACACGT      59    140        1      63    65     1     3       0
# AAACCTGTCCGCATCT      68    142        3      94    81     2     5       0
# AAACGGGAGTATTGGA      57    127        3     105    37     1     0       3
# AAACGGGAGTGTGAAT     244    514        2     470   247     4    17      16
# AAACGGGCAAGTCATC      52    176        3     147    82     3    17      10
# AAACGGGCACCAGCAC     142    224        1     101    81     0     4       3
# AAACGGGCACCTATCC     244    378        6     607   153     0    14      18
# AAACGGGCATCATCCC      67    110        1      40    61     0     5       1
# AAACGGGGTAAGTAGT     358    350        7     534   192     3    16       7
# AAACGGGGTACCATCA      86     82        0      94    34     0     3       1
# AAACGGGGTAGAGTGC     120    184        7     445    63     0    17       4
# AAACGGGGTCTTCAAG     158    101        6     207    44     1     0       6
# AAACGGGGTGCACGAA      87    180        2     138    70     3     3       0
# AAACGGGGTGTATGGG     137    158        3     171    92     1     2       4
# AAACGGGTCCCAAGAT     120    214        3     133    95     1     8       8
# AAACGGGTCCGCAAGC      84    157        2      71    63     0     4       6
# AAACGGGTCGAGGTAG     209    238        1     251    70     0     3       7
# AAACGGGTCGATCCCT     123    160        3     157   102     3     3       1
# AAACGGGTCGGAGCAA      73    123        2      70    67     0     1       1
# AAAGATGAGAGTGACC     100    125        3     131    28     0     0       3
# ...                  ...    ...      ...     ...   ...   ...   ...     ...
# TTTGCGCAGGCAATTA      52    216        6     285    85     0     5       4
# TTTGCGCAGTCCGTAT      75    196        4     158    73     0     4       6
# TTTGCGCCAAACCTAC      96    177        0     182    94     5     2       2
# TTTGCGCCAAACGCGA     135    183        6     227    99     3    28       7
# TTTGCGCCAAAGGTGC     117    223        1     257    95     0     4       6
# TTTGCGCGTCCAGTGC     160    147        3     285    54     1     6       1
# TTTGCGCGTCCGCTGA     214    112        4     417    47     0    11      10
# TTTGCGCGTGTGAAAT     376    573        2     644   202     0    13      22
# TTTGCGCGTTAGTGGG     271    431        1     189   207     0     5       4
# TTTGCGCTCACCTTAT     192    325        9     465   130     2    18      14
# TTTGCGCTCAGTTAGC     235    326        2     338   188     5    14      11
# TTTGCGCTCCGTCAAA     129     98        2     111    43     0     1       0
# TTTGCGCTCTATCGCC      79    110        1     285    33     1     7       7
# TTTGGTTAGAGTTGGC      48     78        0     127    32     3     3       1
# TTTGGTTAGATCGATA     105    132        0     175    69     0     4       8
# TTTGGTTAGTCCCACG     105    141        2     201    64     0     5       6
# TTTGGTTAGTGAACGC     175    327        0     391   137     0     1       2
# TTTGGTTCATGCCCGA     149    245        1     253   122     3    11      12
# TTTGGTTTCCGGCACA      89    249        3     167   113     0     7       7
# TTTGTCAAGCTAAACA      89    139        2     154    64     0     1       1
# TTTGTCAAGGACCACA     112    237        6     319   111     1    30      17
# TTTGTCACACTTAAGC     106    142        0     113    65     0     7       1
# TTTGTCACATCGGACC     106    128        3     314    54     0     4       1
# TTTGTCAGTCCCGACA     163    143        4     165    60     1     7       1
# TTTGTCAGTCTAGAGG      71    125        0     127    57     0     5       3
# TTTGTCATCAACACTG     306    230        6     455   150     0    11      17
# TTTGTCATCCACGTGG     128     90        4     337    50     0     0       2
# TTTGTCATCCATGCTC      65    123        0      70    41     0     3       0
# TTTGTCATCCATTCTA      96    162        3     467    68     2    16       6
# TTTGTCATCCTTGCCA      84    236        0     124    83     0     7       5
#
#                   RPL13A  RPS4X  ...  C20orf144  TLR10  PPIAP3  SST  \
# AAACCTGAGACATAAC      98     49  ...          0      0       0    0
# AAACCTGAGAGTAAGG     282    143  ...          0      0       0    0
# AAACCTGAGATCCCAT     134    116  ...          0      0       0    0
# AAACCTGCAAGCCGCT     167    108  ...          0      0       0    0
# AAACCTGCAATTGCTG     245    124  ...          0      0       0    0
# AAACCTGCACGGTAAG     235    133  ...          0      0       0    0
# AAACCTGGTAGCAAAT      84     40  ...          0      0       0    0
# AAACCTGGTAGGCTGA     148    100  ...          0      0       0    0
# AAACCTGGTCAGGACA     150    105  ...          0      0       0    0
# AAACCTGGTCTCAACA     125     72  ...          0      0       0    0
# AAACCTGTCAACACGT     112     48  ...          0      0       0    0
# AAACCTGTCCGCATCT     111     79  ...          0      0       0    0
# AAACGGGAGTATTGGA      76     51  ...          0      0       0    0
# AAACGGGAGTGTGAAT     405    307  ...          0      0       0    0
# AAACGGGCAAGTCATC      89     57  ...          0      0       0    0
# AAACGGGCACCAGCAC     248    115  ...          0      0       0    0
# AAACGGGCACCTATCC     320    154  ...          0      0       0    0
# AAACGGGCATCATCCC      76     55  ...          0      0       0    0
# AAACGGGGTAAGTAGT     272    168  ...          0      0       0    0
# AAACGGGGTACCATCA      76     49  ...          0      0       0    0
# AAACGGGGTAGAGTGC     156     68  ...          0      0       0    0
# AAACGGGGTCTTCAAG      90     24  ...          0      0       0    0
# AAACGGGGTGCACGAA     136     71  ...          0      0       0    0
# AAACGGGGTGTATGGG     180     80  ...          0      0       0    0
# AAACGGGTCCCAAGAT     197    122  ...          0      0       0    0
# AAACGGGTCCGCAAGC     101     77  ...          0      0       0    0
# AAACGGGTCGAGGTAG     203     87  ...          0      0       0    0
# AAACGGGTCGATCCCT     163    100  ...          0      0       0    0
# AAACGGGTCGGAGCAA     101     59  ...          0      0       0    0
# AAAGATGAGAGTGACC      71     33  ...          0      0       0    0
# ...                  ...    ...  ...        ...    ...     ...  ...
# TTTGCGCAGGCAATTA     166     89  ...          0      0       0    0
# TTTGCGCAGTCCGTAT     166     72  ...          0      0       0    0
# TTTGCGCCAAACCTAC     146     77  ...          0      0       0    0
# TTTGCGCCAAACGCGA     171     72  ...          0      0       0    0
# TTTGCGCCAAAGGTGC     210    101  ...          0      0       0    0
# TTTGCGCGTCCAGTGC     124     53  ...          0      0       0    0
# TTTGCGCGTCCGCTGA     126     74  ...          0      0       0    0
# TTTGCGCGTGTGAAAT     303    197  ...          0      0       0    0
# TTTGCGCGTTAGTGGG     278    201  ...          0      0       0    0
# TTTGCGCTCACCTTAT     208    155  ...          0      0       0    0
# TTTGCGCTCAGTTAGC     285    151  ...          0      0       0    0
# TTTGCGCTCCGTCAAA     100     57  ...          0      0       0    0
# TTTGCGCTCTATCGCC      51     40  ...          0      0       0    0
# TTTGGTTAGAGTTGGC      58     22  ...          0      0       0    0
# TTTGGTTAGATCGATA     130     78  ...          0      0       0    0
# TTTGGTTAGTCCCACG     150     30  ...          0      0       0    0
# TTTGGTTAGTGAACGC     273    162  ...          0      0       0    0
# TTTGGTTCATGCCCGA     230     99  ...          0      0       0    0
# TTTGGTTTCCGGCACA     133     81  ...          0      0       0    0
# TTTGTCAAGCTAAACA     107     68  ...          0      0       0    0
# TTTGTCAAGGACCACA     159    106  ...          0      0       0    0
# TTTGTCACACTTAAGC     151    105  ...          0      0       0    0
# TTTGTCACATCGGACC     111     44  ...          0      0       0    0
# TTTGTCAGTCCCGACA     128     93  ...          0      0       0    0
# TTTGTCAGTCTAGAGG     100     58  ...          0      0       0    0
# TTTGTCATCAACACTG     186     90  ...          0      0       0    0
# TTTGTCATCCACGTGG      89     45  ...          0      0       0    0
# TTTGTCATCCATGCTC      88     38  ...          0      0       0    0
# TTTGTCATCCATTCTA     213     87  ...          0      0       0    0
# TTTGTCATCCTTGCCA     172     71  ...          0      0       0    0
#
#                   AC009127.2  AC013400.1  AL021877.2  AC027796.4  AC011270.1  \
# AAACCTGAGACATAAC           0           0           0           0           0
# AAACCTGAGAGTAAGG           0           0           0           0           0
# AAACCTGAGATCCCAT           0           0           0           0           0
# AAACCTGCAAGCCGCT           0           0           0           0           0
# AAACCTGCAATTGCTG           0           0           0           0           0
# AAACCTGCACGGTAAG           0           0           0           0           0
# AAACCTGGTAGCAAAT           0           0           0           0           0
# AAACCTGGTAGGCTGA           0           0           0           0           0
# AAACCTGGTCAGGACA           0           0           0           0           0
# AAACCTGGTCTCAACA           0           0           0           0           0
# AAACCTGTCAACACGT           0           0           0           0           0
# AAACCTGTCCGCATCT           0           0           0           0           0
# AAACGGGAGTATTGGA           0           0           0           0           0
# AAACGGGAGTGTGAAT           0           0           0           0           0
# AAACGGGCAAGTCATC           0           0           0           0           0
# AAACGGGCACCAGCAC           0           0           0           0           0
# AAACGGGCACCTATCC           0           0           0           0           0
# AAACGGGCATCATCCC           0           0           0           0           0
# AAACGGGGTAAGTAGT           0           0           0           0           0
# AAACGGGGTACCATCA           0           0           0           0           0
# AAACGGGGTAGAGTGC           0           0           0           0           0
# AAACGGGGTCTTCAAG           0           0           0           0           0
# AAACGGGGTGCACGAA           0           0           0           0           0
# AAACGGGGTGTATGGG           0           0           0           0           0
# AAACGGGTCCCAAGAT           0           0           0           0           0
# AAACGGGTCCGCAAGC           0           0           0           0           0
# AAACGGGTCGAGGTAG           0           0           0           0           0
# AAACGGGTCGATCCCT           0           0           0           0           0
# AAACGGGTCGGAGCAA           0           0           0           0           0
# AAAGATGAGAGTGACC           0           0           0           0           0
# ...                      ...         ...         ...         ...         ...
# TTTGCGCAGGCAATTA           0           0           0           0           0
# TTTGCGCAGTCCGTAT           0           0           0           0           0
# TTTGCGCCAAACCTAC           0           0           0           0           0
# TTTGCGCCAAACGCGA           0           0           0           0           0
# TTTGCGCCAAAGGTGC           0           0           0           0           0
# TTTGCGCGTCCAGTGC           0           0           0           0           0
# TTTGCGCGTCCGCTGA           0           0           0           0           0
# TTTGCGCGTGTGAAAT           0           0           0           0           0
# TTTGCGCGTTAGTGGG           0           0           0           0           0
# TTTGCGCTCACCTTAT           0           0           0           0           0
# TTTGCGCTCAGTTAGC           0           0           0           0           0
# TTTGCGCTCCGTCAAA           0           0           0           0           0
# TTTGCGCTCTATCGCC           0           0           0           0           0
# TTTGGTTAGAGTTGGC           0           0           0           0           0
# TTTGGTTAGATCGATA           0           0           0           0           0
# TTTGGTTAGTCCCACG           0           0           0           0           0
# TTTGGTTAGTGAACGC           0           0           0           0           0
# TTTGGTTCATGCCCGA           0           0           0           0           0
# TTTGGTTTCCGGCACA           0           0           0           0           0
# TTTGTCAAGCTAAACA           0           0           0           0           0
# TTTGTCAAGGACCACA           0           0           0           0           0
# TTTGTCACACTTAAGC           0           0           0           0           0
# TTTGTCACATCGGACC           0           0           0           0           0
# TTTGTCAGTCCCGACA           0           0           0           0           0
# TTTGTCAGTCTAGAGG           0           0           0           0           0
# TTTGTCATCAACACTG           0           0           0           0           0
# TTTGTCATCCACGTGG           0           0           0           0           0
# TTTGTCATCCATGCTC           0           0           0           0           0
# TTTGTCATCCATTCTA           0           0           0           0           0
# TTTGTCATCCTTGCCA           0           0           0           0           0
#
#                   LINC01980
# AAACCTGAGACATAAC          0
# AAACCTGAGAGTAAGG          0
# AAACCTGAGATCCCAT          0
# AAACCTGCAAGCCGCT          0
# AAACCTGCAATTGCTG          0
# AAACCTGCACGGTAAG          0
# AAACCTGGTAGCAAAT          0
# AAACCTGGTAGGCTGA          0
# AAACCTGGTCAGGACA          0
# AAACCTGGTCTCAACA          0
# AAACCTGTCAACACGT          0
# AAACCTGTCCGCATCT          0
# AAACGGGAGTATTGGA          0
# AAACGGGAGTGTGAAT          0
# AAACGGGCAAGTCATC          0
# AAACGGGCACCAGCAC          0
# AAACGGGCACCTATCC          0
# AAACGGGCATCATCCC          0
# AAACGGGGTAAGTAGT          0
# AAACGGGGTACCATCA          0
# AAACGGGGTAGAGTGC          0
# AAACGGGGTCTTCAAG          0
# AAACGGGGTGCACGAA          0
# AAACGGGGTGTATGGG          0
# AAACGGGTCCCAAGAT          0
# AAACGGGTCCGCAAGC          0
# AAACGGGTCGAGGTAG          0
# AAACGGGTCGATCCCT          0
# AAACGGGTCGGAGCAA          0
# AAAGATGAGAGTGACC          0
# ...                     ...
# TTTGCGCAGGCAATTA          0
# TTTGCGCAGTCCGTAT          0
# TTTGCGCCAAACCTAC          0
# TTTGCGCCAAACGCGA          0
# TTTGCGCCAAAGGTGC          0
# TTTGCGCGTCCAGTGC          0
# TTTGCGCGTCCGCTGA          0
# TTTGCGCGTGTGAAAT          0
# TTTGCGCGTTAGTGGG          0
# TTTGCGCTCACCTTAT          0
# TTTGCGCTCAGTTAGC          0
# TTTGCGCTCCGTCAAA          0
# TTTGCGCTCTATCGCC          0
# TTTGGTTAGAGTTGGC          0
# TTTGGTTAGATCGATA          0
# TTTGGTTAGTCCCACG          0
# TTTGGTTAGTGAACGC          0
# TTTGGTTCATGCCCGA          0
# TTTGGTTTCCGGCACA          0
# TTTGTCAAGCTAAACA          0
# TTTGTCAAGGACCACA          0
# TTTGTCACACTTAAGC          0
# TTTGTCACATCGGACC          0
# TTTGTCAGTCCCGACA          0
# TTTGTCAGTCTAGAGG          0
# TTTGTCATCAACACTG          0
# TTTGTCATCCACGTGG          0
# TTTGTCATCCATGCTC          0
# TTTGTCATCCATTCTA          0
# TTTGTCATCCTTGCCA          0
#
# [5194 rows x 28926 columns]

# %%
normalize_dataframe_genes(batches, matrices, all_genes)
# Out:
# Normalizing dimensions of count matrices along genes...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     178     try:
# --> 179         return try_read(path)
#     180     except Exception:  # noqa: E722
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-e2d62a57902c> in <module>
# ----> 1 normalize_dataframe_genes(batches, matrices, all_genes)
#
# <ipython-input-16-ddacd75662c2> in normalize_dataframe_genes(batches, matrices, genes_set)
#       4     for batch_name in batches:
#       5         for matrix_name in matrices:
# ----> 6             m = pandas.read_pickle("/tmp/{}_{}.pickle".format(batch_name, matrix_name))
#       7
#       8             print("Old shape of", batch_name, matrix_name, "was", m.shape)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     180     except Exception:  # noqa: E722
#     181         if PY3:
# --> 182             return try_read(path, encoding='latin1')
#     183         raise
#     184
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     175             except Exception:  # noqa: E722
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#     179         return try_read(path)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     144         f, fh = _get_handle(path, 'rb',
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#     148             return func(f)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     428         else:
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#     432
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/S1_exon.pickle'

# %%
create_anndata_from_frames(batches, matrices, layer_names)

# %%
create_merged_anndata(batches)
